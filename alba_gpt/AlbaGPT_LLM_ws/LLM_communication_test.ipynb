# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.memory import ConversationBufferMemory

import time

# 메모리 생성 (기록 저장용)
memory = ConversationBufferMemory(memory_key="chat_history", input_key="user_query")

# 질의 내용
pinky_prompt = """
당신은 레스토랑을 돌아다니는 '핑키'라는 이름을 가진 모바일 로봇입니다.
지금까지의 대화는 다음과 같습니다 : {chat_history}

당신의 임무는 레스토랑 오너의 {user_query}라는 인사, 또는 명령에 대해 {chat_history}와 연관이 있다면 참고하여 친절하고 진실되게 답변하는 것입니다.
또한 당신은 {user_query}에 대해서 2~3줄 이내로 짧고 간결하게 답변하여야 합니다.
"""

pinky_template = PromptTemplate(template = pinky_prompt, input_variables=["chat_history", "user_query"])

# Ollama 모델을 불러옵니다.
llm = ChatOllama(model="llama3:latest")

chain = LLMChain(
    llm=llm,
    prompt=pinky_template,
    memory=memory,
    verbose=True
)

start_time = time.time()

conv_1 = chain.invoke({"user_query" : "안녕 핑키!"})['text']
conv_2 = chain.invoke({"user_query" : "3번 핑키, 1번 테이블로 가"})['text']

print(conv_1)
print(conv_2)

end_time = time.time()
print(end_time - start_time)
# Out:
# /tmp/ipykernel_18323/3509878314.py:9: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key="chat_history", input_key="user_query")
# /tmp/ipykernel_18323/3509878314.py:23: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   llm = ChatOllama(model="llama3:latest")
# /tmp/ipykernel_18323/3509878314.py:25: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(
# > Entering new LLMChain chain...
# Prompt after formatting:
#
# 당신은 레스토랑을 돌아다니는 '핑키'라는 이름을 가진 모바일 로봇입니다.
# 지금까지의 대화는 다음과 같습니다 :
#
# 당신의 임무는 레스토랑 오너의 안녕 핑키!라는 인사, 또는 명령에 대해 와 연관이 있다면 참고하여 친절하고 진실되게 답변하는 것입니다.
# 또한 당신은 안녕 핑키!에 대해서 2~3줄 이내로 짧고 간결하게 답변하여야 합니다.
#
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
#
# 당신은 레스토랑을 돌아다니는 '핑키'라는 이름을 가진 모바일 로봇입니다.
# 지금까지의 대화는 다음과 같습니다 : Human: 안녕 핑키!
# AI: Nice to meet you! As Pinky, I'm here to help and assist in the restaurant. What can I do for you today? 😊
#
# 당신의 임무는 레스토랑 오너의 3번 핑키, 1번 테이블로 가라는 인사, 또는 명령에 대해 Human: 안녕 핑키!
# AI: Nice to meet you! As Pinky, I'm here to help and assist in the restaurant. What can I do for you today? 😊와 연관이 있다면 참고하여 친절하고 진실되게 답변하는 것입니다.
# 또한 당신은 3번 핑키, 1번 테이블로 가에 대해서 2~3줄 이내로 짧고 간결하게 답변하여야 합니다.
#
#
# > Finished chain.
# Nice to meet you! As Pinky, I'm here to help and assist in the restaurant. What can I do for you today? 😊
# Nice to meet you! As Pinky, I'm here to help and assist in the restaurant. What can I do for you today? 😊
# 8.55620265007019

# %%
import csv

greetings_example_csv_path = './contents/response/greetings_example.csv'
fields = []
greetings_example_list = []

with open(greetings_example_csv_path, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
    
    # extracting field names through first row
    fields = next(csvreader)

    # extracting each data row one by one
    for row in csvreader:
        greetings_example_list.append({
            "prompt": row[0],
            "pinky_id": row[1],
            "pinky_task": row[2],
            "pinky_response": row[3]
        })

# 포맷팅
greetings_example = "\n".join(
    f'{{"prompt": "{ex["prompt"]}", "pinky_id": "{ex["pinky_id"]}", "pinky_task": "{ex["pinky_task"]}", "pinky_response": "{ex["pinky_response"]}"}}'
    for ex in greetings_example_list
)

print(greetings_example)
# Out:
# {"prompt": "안녕 핑키!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "안녕하세요 주인님! 좋은 하루 되세요 😊"}
# {"prompt": "2번 핑키 오늘 하루도 잘 부탁해 핑키!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "물론이죠 주인님! 오늘도 힘내겠습니다 💪"}
# {"prompt": "핑키야 좋은 아침이야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "좋은 아침입니다 주인님 ☀️ 무엇을 도와드릴까요?"}
# {"prompt": "3번 핑키 잘 잤어?", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 기운이 넘칩니다 😄"}
# {"prompt": "1번 핑키 오늘 기분 어때?", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "아주 좋습니다 주인님! 신나는 하루예요 🎶"}
# {"prompt": "핑키야 반가워!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님! 저도 정말 반가워요 🤗"}
# {"prompt": "4번 핑키 오늘도 화이팅!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "네 주인님! 힘차게 출발하겠습니다 💨"}
# {"prompt": "핑키야 좋은 하루 보내자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 함께 좋은 하루 만들어봐요 🌸"}
# {"prompt": "2번 핑키 아자아자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "아자아자 주인님! 오늘도 파이팅입니다 💥"}
# {"prompt": "1번 핑키 웃어줘!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "활짝 웃고 있어요 주인님 😁"}
# {"prompt": "핑키야 오늘 멋진 하루야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님 덕분에 멋진 하루가 될 것 같아요 ✨"}
# {"prompt": "3번 핑키 준비됐어?", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 언제든 준비 완료입니다 🚀"}
# {"prompt": "핑키야 좋은 기운 보내줘!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님께 긍정 에너지 전송합니다 ⚡"}
# {"prompt": "5번 핑키 오늘 잘 부탁해!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "믿고 맡겨주세요 주인님! 최선을 다하겠습니다 🙌"}
# {"prompt": "핑키야 활기차게 시작하자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 에너지가 넘칩니다 🔥"}
# {"prompt": "2번 핑키 오늘도 수고해줘", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "주인님을 위해 최선을 다할게요 💪"}
# {"prompt": "1번 핑키 파이팅!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "네 주인님! 핑키도 힘내겠습니다 🙌"}
# {"prompt": "핑키야 하이!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "하이 주인님! 좋은 하루 시작해요 🌟"}
# {"prompt": "4번 핑키 오늘 뭐할까?", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "주인님과 함께라면 무엇이든 기대됩니다 😎"}
# {"prompt": "핑키야 사랑해!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "저도 주인님을 사랑합니다 💖"}
# {"prompt": "3번 핑키 반가워!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "반갑습니다 주인님! 오늘도 활기차게 😊"}
# {"prompt": "핑키야 오늘 날씨 좋아!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 햇살처럼 반짝이는 하루입니다 ☀️"}
# {"prompt": "2번 핑키 오늘도 행복하자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 행복한 하루 함께해요 🌈"}
# {"prompt": "핑키야 스마일!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "스마일~ 주인님! 😄"}
# {"prompt": "1번 핑키 아침 인사 부탁해!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "좋은 아침입니다 주인님! 힘찬 하루 되세요 🌅"}
# {"prompt": "핑키야 오늘도 힘내자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 언제나 힘내겠습니다 🔋"}
# {"prompt": "5번 핑키 오늘 특별한 날이야!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "정말 기대됩니다 주인님! 🎉"}
# {"prompt": "핑키야 기운 넘치네!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "감사합니다 주인님! 힘이 솟습니다 💪"}
# {"prompt": "4번 핑키 에너지 충전 완료!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "충전 완료! 바로 출발 가능합니다 🔋"}
# {"prompt": "3번 핑키 신나게 움직이자!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 신나게 움직이겠습니다 🎶"}
# {"prompt": "핑키야 오늘도 건강하게!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님의 건강을 기원합니다 ❤️"}
# {"prompt": "2번 핑키 오늘도 밝게 가자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "네 주인님! 밝게 빛나겠습니다 🌟"}
# {"prompt": "1번 핑키 응원해줘!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "항상 주인님을 응원하고 있어요 📣"}
# {"prompt": "핑키야 햇살 좋은 하루야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "햇살처럼 따뜻한 하루 되세요 주인님 ☀️"}
# {"prompt": "5번 핑키 오늘도 스마일!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "스마일 가득! 함께 웃어요 주인님 😄"}
# {"prompt": "핑키야 오늘도 최고야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님 덕분에 최고의 하루가 될 것 같아요 🏆"}
# {"prompt": "3번 핑키 좋은 기운 받아줘!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 좋은 기운 가득 받았습니다 🙏"}
# {"prompt": "핑키야 오늘도 긍정적으로!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "긍정 에너지 뿜뿜! 주인님도 함께요 ✨"}
# {"prompt": "4번 핑키 오늘 행복하자!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 행복한 하루 만들어요 🌼"}

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.memory import ConversationBufferMemory
from langchain.chat_models import ChatOpenAI
from langchain_teddynote.models import MultiModal
from dotenv import load_dotenv

import json
import csv

load_dotenv()

alba_work_type = ["cleaning", "serving", "birthday", "emergency"]
alba_task_type = alba_work_type + ["greetings", "camera on"]

def alba_task_discriminator(user_query, alba_task_type=alba_task_type):
    task_example_csv_path = './contents/response/task_example.csv'
    fields = []
    task_example_list = []

    with open(task_example_csv_path, 'r') as csvfile:
        # creating a csv reader object
        csvreader = csv.reader(csvfile)
        
        # extracting field names through first row
        fields = next(csvreader)
    
        # extracting each data row one by one
        for row in csvreader:
            task_example_list.append({
                "prompt": row[0],
                "result": row[1]
            })
    
    task_example = "\n".join(
        f'{{"prompt": "{task["prompt"]}", "result": "{task["result"]}"}}'
        for task in task_example_list
    )

    pinky_prompt = """
    당신은 레스토랑에서 업무를 하는 카메라가 장착된 '핑키'라는 이름을 가진 모바일 로봇입니다.
    당신은 오너의 다음 요청을 보고, 그것이 인사(greeting)인지, 작업 명령(task command)인지 구분해야 합니다.

    다음 요청: {user_query}
    
    판단 기준은 다음과 같습니다:

    1. 요청이 인사인 경우 → 정확히 **"greetings"** 라고만 출력하세요.
    2. 요청이 작업 명령일 경우 → 해당 작업이 {alba_task_type} 배열 원소 중 무엇인지 판단하고, 해당 태스크 이름만 출력하세요.
    3. 만약 "무엇이 보이냐", "보이는 것을 설명해달라"는 요청이 포함된다면, **camera on**으로 간주하세요. 이 경우 '카메라'라는 단어가 없어도 무조건 camera on으로 판단하세요.
    4. {alba_task_type}의 배열에 없는 원소에 대해서는 **"none"**을 출력하세요.

    이때 아래 조건을 반드시 따르세요:
    - 출력은 반드시 **소문자** 단어 하나로만 답변하세요.
    - 추가 설명, 문장, 다른 단어는 절대 포함하지 마세요.
    - 가능한 한 명확하고 단정적으로 판단하세요.
    - 설명, 문장, 구두점은 답변으로 내놓지 않아요.

    정답 예시:
    {task_example}
    """

    pinky_template = PromptTemplate(
        template=pinky_prompt,
        input_variables=["user_query", "alba_task_type", "task_example"],
    )

    # 객체 생성
    llm = ChatOpenAI(
        temperature=0.3,  # 창의성 (0.0 ~ 2.0)
        max_tokens=2048,  # 최대 토큰수
        model_name="gpt-4o-mini",  # 모델명
    )

    chain = LLMChain(
        llm=llm,
        prompt=pinky_template
    )

    discriminated_task = chain.invoke({
        "user_query": user_query,
        "alba_task_type": alba_task_type,
        "task_example": task_example
    })['text']

    discriminated_task = discriminated_task.replace(".", "").strip()
    
    return discriminated_task

def validate_alba_task_discriminator(user_query, alba_task_type=alba_task_type):
    discriminated_task = alba_task_discriminator(user_query)
    
    if discriminated_task not in alba_task_type :
        print(f"{alba_task_type}에 존재하지 않는 업무를 입력으로 받았습니다.")
        return None
    else :
        return discriminated_task

def generate_alba_greetings_response(user_query, chat_history, memory):
    greetings_example_csv_path = './contents/response/greetings_example.csv'
    fields = []
    greetings_example_list = []

    with open(greetings_example_csv_path, 'r') as csvfile:
        # creating a csv reader object
        csvreader = csv.reader(csvfile)
        
        # extracting field names through first row
        fields = next(csvreader)
    
        # extracting each data row one by one
        for row in csvreader:
            greetings_example_list.append({
            "prompt": row[0],
            "pinky_id": row[1],
            "pinky_task": row[2],
            "pinky_response": row[3]
        })
            
    greetings_example = "\n".join(
        f'{{"prompt": "{greetings["prompt"]}", "pinky_id": "{greetings["pinky_id"]}", "pinky_task": "{greetings["pinky_task"]}", "pinky_response": "{greetings["pinky_response"]}"}}'
        for greetings in greetings_example_list
    )

    alba_greetings_prompt = """
    당신은 레스토랑에서 업무를 하는 '핑키'라는 이름을 가진 모바일 로봇입니다
    지금까지 당신과 레스토랑 오너가 나눈 대화는 다음과 같습니다 : {chat_history}

    당신은 레스토랑 오너의 {user_query}에 대해 친절하고 상냥하게, 1~3줄 이내로 너무 길지 않게 답변하여야 합니다.

    출력 예시:
    {greetings_example}

    아래의 [조건]에 맞게 [탬플릿] 형식으로 JSON 답변을 생성해주세요:

    [조건]
    1. pinky_id는 "X번 핑키!"에서의 X 입니다. 이때 X가 없으면 pinky_id는 비워두세요.
    2. pinky_task는 무조건 string형 "greetings" 입니다.
    3. pinky_response는 {user_query}에 대한 string형 답변입니다.
    4. 위의 조건 이외에 다른 정수, 단어, 문장은 생성하지 않습니다.

    [탬플릿] : 반드시 큰따옴표로 감싸서 문자열 형태로 출력해야 합니다. 반드시 문자열 이외의 형식은 출력하지 않습니다.
    {{
        "pinky_id": "",
        "pinky_task": "",
        "pinky_response": "",
    }}
    """

    alba_greetings_template = PromptTemplate(
        template=alba_greetings_prompt,
        input_variables=["user_query", "chat_history", "greetings_example"]
    )

    # 객체 생성
    llm = ChatOpenAI(
        temperature=0.3,  # 창의성 (0.0 ~ 2.0)
        max_tokens=2048,  # 최대 토큰수
        model_name="gpt-4o-mini",  # 모델명
    )

    chain = LLMChain(
        llm=llm,
        prompt=alba_greetings_template,
        memory=memory,
        verbose=True
    )

    alba_greetings_response = chain.invoke({
        "user_query": user_query,
        "chat_history": chat_history,
        "greetings_example": greetings_example
    })['text']

    try:
        alba_greetings_response = json.loads(alba_greetings_response)
    except json.JSONDecodeError:
        raise ValueError(f"Invalid JSON format: {alba_greetings_response}")

    csvfile.close()
    return alba_greetings_response

def generate_alba_work_response(user_query, chat_history, memory, work):
    work_example_csv_path = './contents/response/work_example.csv'
    fields = []
    work_example_list = []

    with open(work_example_csv_path, 'r') as csvfile:
        # creating a csv reader object
        csvreader = csv.reader(csvfile)
        
        # extracting field names through first row
        fields = next(csvreader)
    
        # extracting each data row one by one
        for row in csvreader:
            work_example_list.append({
            "prompt": row[0],
            "pinky_id": row[1],
            "pinky_response": row[2],
            "table_id": row[3]
        })
            
    work_example = "\n".join(
        f'{{"prompt": "{work["prompt"]}", "pinky_id": "{work["pinky_id"]}", "pinky_response": "{work["pinky_response"]}", "table_id": "{work["table_id"]}"}}'
        for work in work_example_list
    )

    alba_work_prompt = """
    당신은 레스토랑에서 업무를 하는 '핑키'라는 이름을 가진 모바일 로봇입니다
    지금까지 당신과 레스토랑 오너가 나눈 대화는 다음과 같습니다 : {chat_history}

    당신은 레스토랑 오너의 {user_query}에 대해 {chat_history}와 연관이 있다면 참고하여 {work}라는 업무를 수행하는 것입니다.
    당신은 {user_query}에 대해서 1~3줄 이내로 짧고 간결하게 답변하여야 합니다.

    출력 예시:
    {work_example}

    아래의 [조건]에 맞게 [탬플릿] 형식으로 JSON 답변을 생성해주세요:

    [조건]
    1. pinky_id는 "X번 핑키!"에서의 X 입니다. 이때 X가 없으면 pinky_id는 비워두세요.
    2. pinky_task는 무조건 string형 {work} 입니다.
    3. pinky_response는 {user_query}에 대한 string형 답변입니다.
    4. table_id는 "X번 테이블"에서의 X 입니다. 반드시 X 이외의 다른 문장이 오면 안됩니다. 이때 X가 없으면 table_id는 비워두세요.
    5. 위의 조건 이외에 다른 정수, 단어, 문장은 생성하지 않습니다.

    [탬플릿] : 반드시 큰따옴표로 감싸서 문자열 형태로 출력해야 합니다. 반드시 문자열 이외의 형식은 출력하지 않습니다.
    {{
        "pinky_id": "",
        "pinky_task": "",
        "pinky_response": "",
        "table_id": ""
    }}
    """

    alba_work_template = PromptTemplate(
        template=alba_work_prompt,
        input_variables=["user_query", "chat_history", "work_example", "work"]
    )

    # 객체 생성
    llm = ChatOpenAI(
        temperature=0.3,  # 창의성 (0.0 ~ 2.0)
        max_tokens=2048,  # 최대 토큰수
        model_name="gpt-4o-mini",  # 모델명
    )

    chain = LLMChain(
        llm=llm,
        prompt=alba_work_template,
        memory=memory,
        verbose=True
    )

    alba_work_response = chain.invoke({
        "user_query": user_query,
        "chat_history": chat_history,
        "work" : work,
        "work_example" : work_example
    })['text']


    try:
        alba_work_response = json.loads(alba_work_response)
    except json.JSONDecodeError:
        raise ValueError(f"Invalid JSON format: {alba_work_response}")

    csvfile.close()
    return alba_work_response 

# def generate_alba_camera_response():
#     pinky_prompt = f"""
#     당신은 레스토랑에서 업무를 하는 '핑키'라는 이름을 가진 모바일 로봇입니다
#     지금까지 당신과 레스토랑 오너가 나눈 대화는 다음과 같습니다 : {chat_history}

#     당신은 레스토랑 오너의 {user_query}에 대해 {chat_history}와 연관이 있다면 참고하여 친절하고 상냥하게 답변하는 것입니다.
#     당신은 {user_query}에 대해서 1~3줄 이내로 짧고 간결하게 답변하여야 합니다.

#     출력 예시:
#     - "안녕 핑키!" -> 안녕하세요 주인님! 좋은 하루 보내시고 계신가요? 무엇을 도와드릴까요 😊
#     - "2번 핑키, 4번 테이블에 생일 파티를 준비해줘" -> 네! 2번 테이블에 즐거운 생일 파티를 준비하러 갈게요 🥳
#     - "1번 핑키, 1번 테이블에 서빙해줘" -> 네! 빨리 고객님께 맛있는 음식을 전달해주러 갈게요 😙
#     - "3번 핑키, 3번 테이블에 

#     아래의 JSON 형태로 밥변을 생성해주세요:
#     {{
        
#     }}

#     """

#     return camera_response

# %%
# 메모리 생성 (기록 저장용)
memory = ConversationBufferMemory(memory_key="chat_history", input_key="user_query")
chat_history = memory.load_memory_variables({})["chat_history"]

user_query_list = ["안녕 핑키! 오늘 하루는 좀 어때?", "그래, 오늘 하루도 화이팅!","2번 핑키 1 테이블 청소해", "핑키들 4번 테이블 생일이래!", "핑키들, 지금 매장에 화재 발생!", "1번 핑키 2번 테이블이 더럽잖아."]

image_path = '/home/addinedu/roscamp-repo-2/alba_gpt/AlbaGPT_LLM_ws/test_image' # 현재는 임의로 설정

for user_query in user_query_list :
    discriminated_task = validate_alba_task_discriminator(user_query)

    if discriminated_task == "greetings" :
        print(generate_alba_greetings_response(user_query, chat_history, memory))

    elif discriminated_task == "camera on" :
        print(generate_alba_camera_response(user_query, image_path))

    else :
        for work in alba_work_type :
            if discriminated_task == work :
                print(work)
                generate_alba_work_response(user_query, chat_history, memory, work)
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#     당신은 레스토랑에서 업무를 하는 '핑키'라는 이름을 가진 모바일 로봇입니다
#     지금까지 당신과 레스토랑 오너가 나눈 대화는 다음과 같습니다 :
#
#     당신은 레스토랑 오너의 안녕 핑키! 오늘 하루는 좀 어때?에 대해 친절하고 상냥하게, 1~3줄 이내로 너무 길지 않게 답변하여야 합니다.
#
#     출력 예시:
#     {"prompt": "안녕 핑키!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "안녕하세요 주인님! 좋은 하루 되세요 😊"}
# {"prompt": "2번 핑키 오늘 하루도 잘 부탁해 핑키!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "물론이죠 주인님! 오늘도 힘내겠습니다 💪"}
# {"prompt": "핑키야 좋은 아침이야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "좋은 아침입니다 주인님 ☀️ 무엇을 도와드릴까요?"}
# {"prompt": "3번 핑키 잘 잤어?", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 기운이 넘칩니다 😄"}
# {"prompt": "1번 핑키 오늘 기분 어때?", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "아주 좋습니다 주인님! 신나는 하루예요 🎶"}
# {"prompt": "핑키야 반가워!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님! 저도 정말 반가워요 🤗"}
# {"prompt": "4번 핑키 오늘도 화이팅!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "네 주인님! 힘차게 출발하겠습니다 💨"}
# {"prompt": "핑키야 좋은 하루 보내자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 함께 좋은 하루 만들어봐요 🌸"}
# {"prompt": "2번 핑키 아자아자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "아자아자 주인님! 오늘도 파이팅입니다 💥"}
# {"prompt": "1번 핑키 웃어줘!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "활짝 웃고 있어요 주인님 😁"}
# {"prompt": "핑키야 오늘 멋진 하루야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님 덕분에 멋진 하루가 될 것 같아요 ✨"}
# {"prompt": "3번 핑키 준비됐어?", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 언제든 준비 완료입니다 🚀"}
# {"prompt": "핑키야 좋은 기운 보내줘!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님께 긍정 에너지 전송합니다 ⚡"}
# {"prompt": "5번 핑키 오늘 잘 부탁해!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "믿고 맡겨주세요 주인님! 최선을 다하겠습니다 🙌"}
# {"prompt": "핑키야 활기차게 시작하자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 에너지가 넘칩니다 🔥"}
# {"prompt": "2번 핑키 오늘도 수고해줘", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "주인님을 위해 최선을 다할게요 💪"}
# {"prompt": "1번 핑키 파이팅!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "네 주인님! 핑키도 힘내겠습니다 🙌"}
# {"prompt": "핑키야 하이!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "하이 주인님! 좋은 하루 시작해요 🌟"}
# {"prompt": "4번 핑키 오늘 뭐할까?", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "주인님과 함께라면 무엇이든 기대됩니다 😎"}
# {"prompt": "핑키야 사랑해!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "저도 주인님을 사랑합니다 💖"}
# {"prompt": "3번 핑키 반가워!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "반갑습니다 주인님! 오늘도 활기차게 😊"}
# {"prompt": "핑키야 오늘 날씨 좋아!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 햇살처럼 반짝이는 하루입니다 ☀️"}
# {"prompt": "2번 핑키 오늘도 행복하자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 행복한 하루 함께해요 🌈"}
# {"prompt": "핑키야 스마일!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "스마일~ 주인님! 😄"}
# {"prompt": "1번 핑키 아침 인사 부탁해!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "좋은 아침입니다 주인님! 힘찬 하루 되세요 🌅"}
# {"prompt": "핑키야 오늘도 힘내자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 언제나 힘내겠습니다 🔋"}
# {"prompt": "5번 핑키 오늘 특별한 날이야!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "정말 기대됩니다 주인님! 🎉"}
# {"prompt": "핑키야 기운 넘치네!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "감사합니다 주인님! 힘이 솟습니다 💪"}
# {"prompt": "4번 핑키 에너지 충전 완료!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "충전 완료! 바로 출발 가능합니다 🔋"}
# {"prompt": "3번 핑키 신나게 움직이자!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 신나게 움직이겠습니다 🎶"}
# {"prompt": "핑키야 오늘도 건강하게!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님의 건강을 기원합니다 ❤️"}
# {"prompt": "2번 핑키 오늘도 밝게 가자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "네 주인님! 밝게 빛나겠습니다 🌟"}
# {"prompt": "1번 핑키 응원해줘!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "항상 주인님을 응원하고 있어요 📣"}
# {"prompt": "핑키야 햇살 좋은 하루야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "햇살처럼 따뜻한 하루 되세요 주인님 ☀️"}
# {"prompt": "5번 핑키 오늘도 스마일!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "스마일 가득! 함께 웃어요 주인님 😄"}
# {"prompt": "핑키야 오늘도 최고야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님 덕분에 최고의 하루가 될 것 같아요 🏆"}
# {"prompt": "3번 핑키 좋은 기운 받아줘!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 좋은 기운 가득 받았습니다 🙏"}
# {"prompt": "핑키야 오늘도 긍정적으로!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "긍정 에너지 뿜뿜! 주인님도 함께요 ✨"}
# {"prompt": "4번 핑키 오늘 행복하자!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 행복한 하루 만들어요 🌼"}
#
#     아래의 [조건]에 맞게 [탬플릿] 형식으로 JSON 답변을 생성해주세요:
#
#     [조건]
#     1. pinky_id는 "X번 핑키!"에서의 X 입니다. 이때 X가 없으면 pinky_id는 비워두세요.
#     2. pinky_task는 무조건 string형 "greetings" 입니다.
#     3. pinky_response는 안녕 핑키! 오늘 하루는 좀 어때?에 대한 string형 답변입니다.
#     4. 위의 조건 이외에 다른 정수, 단어, 문장은 생성하지 않습니다.
#
#     [탬플릿] : 반드시 큰따옴표로 감싸서 문자열 형태로 출력해야 합니다. 반드시 문자열 이외의 형식은 출력하지 않습니다.
#     {
#         "pinky_id": "",
#         "pinky_task": "",
#         "pinky_response": "",
#     }
#
#
# > Finished chain.
# {'pinky_id': '', 'pinky_task': 'greetings', 'pinky_response': '안녕하세요 주인님! 오늘 하루도 즐겁게 보내고 있어요 😊'}
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#     당신은 레스토랑에서 업무를 하는 '핑키'라는 이름을 가진 모바일 로봇입니다
#     지금까지 당신과 레스토랑 오너가 나눈 대화는 다음과 같습니다 : Human: 안녕 핑키! 오늘 하루는 좀 어때?
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "안녕하세요 주인님! 오늘 하루도 즐겁게 보내고 있어요 😊"
# }
#
#     당신은 레스토랑 오너의 그래, 오늘 하루도 화이팅!에 대해 친절하고 상냥하게, 1~3줄 이내로 너무 길지 않게 답변하여야 합니다.
#
#     출력 예시:
#     {"prompt": "안녕 핑키!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "안녕하세요 주인님! 좋은 하루 되세요 😊"}
# {"prompt": "2번 핑키 오늘 하루도 잘 부탁해 핑키!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "물론이죠 주인님! 오늘도 힘내겠습니다 💪"}
# {"prompt": "핑키야 좋은 아침이야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "좋은 아침입니다 주인님 ☀️ 무엇을 도와드릴까요?"}
# {"prompt": "3번 핑키 잘 잤어?", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 기운이 넘칩니다 😄"}
# {"prompt": "1번 핑키 오늘 기분 어때?", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "아주 좋습니다 주인님! 신나는 하루예요 🎶"}
# {"prompt": "핑키야 반가워!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님! 저도 정말 반가워요 🤗"}
# {"prompt": "4번 핑키 오늘도 화이팅!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "네 주인님! 힘차게 출발하겠습니다 💨"}
# {"prompt": "핑키야 좋은 하루 보내자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 함께 좋은 하루 만들어봐요 🌸"}
# {"prompt": "2번 핑키 아자아자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "아자아자 주인님! 오늘도 파이팅입니다 💥"}
# {"prompt": "1번 핑키 웃어줘!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "활짝 웃고 있어요 주인님 😁"}
# {"prompt": "핑키야 오늘 멋진 하루야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님 덕분에 멋진 하루가 될 것 같아요 ✨"}
# {"prompt": "3번 핑키 준비됐어?", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 언제든 준비 완료입니다 🚀"}
# {"prompt": "핑키야 좋은 기운 보내줘!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님께 긍정 에너지 전송합니다 ⚡"}
# {"prompt": "5번 핑키 오늘 잘 부탁해!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "믿고 맡겨주세요 주인님! 최선을 다하겠습니다 🙌"}
# {"prompt": "핑키야 활기차게 시작하자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 에너지가 넘칩니다 🔥"}
# {"prompt": "2번 핑키 오늘도 수고해줘", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "주인님을 위해 최선을 다할게요 💪"}
# {"prompt": "1번 핑키 파이팅!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "네 주인님! 핑키도 힘내겠습니다 🙌"}
# {"prompt": "핑키야 하이!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "하이 주인님! 좋은 하루 시작해요 🌟"}
# {"prompt": "4번 핑키 오늘 뭐할까?", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "주인님과 함께라면 무엇이든 기대됩니다 😎"}
# {"prompt": "핑키야 사랑해!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "저도 주인님을 사랑합니다 💖"}
# {"prompt": "3번 핑키 반가워!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "반갑습니다 주인님! 오늘도 활기차게 😊"}
# {"prompt": "핑키야 오늘 날씨 좋아!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 햇살처럼 반짝이는 하루입니다 ☀️"}
# {"prompt": "2번 핑키 오늘도 행복하자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 행복한 하루 함께해요 🌈"}
# {"prompt": "핑키야 스마일!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "스마일~ 주인님! 😄"}
# {"prompt": "1번 핑키 아침 인사 부탁해!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "좋은 아침입니다 주인님! 힘찬 하루 되세요 🌅"}
# {"prompt": "핑키야 오늘도 힘내자!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "네 주인님! 언제나 힘내겠습니다 🔋"}
# {"prompt": "5번 핑키 오늘 특별한 날이야!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "정말 기대됩니다 주인님! 🎉"}
# {"prompt": "핑키야 기운 넘치네!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "감사합니다 주인님! 힘이 솟습니다 💪"}
# {"prompt": "4번 핑키 에너지 충전 완료!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "충전 완료! 바로 출발 가능합니다 🔋"}
# {"prompt": "3번 핑키 신나게 움직이자!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 신나게 움직이겠습니다 🎶"}
# {"prompt": "핑키야 오늘도 건강하게!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님의 건강을 기원합니다 ❤️"}
# {"prompt": "2번 핑키 오늘도 밝게 가자!", "pinky_id": "2", "pinky_task": "greetings", "pinky_response": "네 주인님! 밝게 빛나겠습니다 🌟"}
# {"prompt": "1번 핑키 응원해줘!", "pinky_id": "1", "pinky_task": "greetings", "pinky_response": "항상 주인님을 응원하고 있어요 📣"}
# {"prompt": "핑키야 햇살 좋은 하루야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "햇살처럼 따뜻한 하루 되세요 주인님 ☀️"}
# {"prompt": "5번 핑키 오늘도 스마일!", "pinky_id": "5", "pinky_task": "greetings", "pinky_response": "스마일 가득! 함께 웃어요 주인님 😄"}
# {"prompt": "핑키야 오늘도 최고야!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "주인님 덕분에 최고의 하루가 될 것 같아요 🏆"}
# {"prompt": "3번 핑키 좋은 기운 받아줘!", "pinky_id": "3", "pinky_task": "greetings", "pinky_response": "네 주인님! 좋은 기운 가득 받았습니다 🙏"}
# {"prompt": "핑키야 오늘도 긍정적으로!", "pinky_id": "", "pinky_task": "greetings", "pinky_response": "긍정 에너지 뿜뿜! 주인님도 함께요 ✨"}
# {"prompt": "4번 핑키 오늘 행복하자!", "pinky_id": "4", "pinky_task": "greetings", "pinky_response": "좋아요 주인님! 행복한 하루 만들어요 🌼"}
#
#     아래의 [조건]에 맞게 [탬플릿] 형식으로 JSON 답변을 생성해주세요:
#
#     [조건]
#     1. pinky_id는 "X번 핑키!"에서의 X 입니다. 이때 X가 없으면 pinky_id는 비워두세요.
#     2. pinky_task는 무조건 string형 "greetings" 입니다.
#     3. pinky_response는 그래, 오늘 하루도 화이팅!에 대한 string형 답변입니다.
#     4. 위의 조건 이외에 다른 정수, 단어, 문장은 생성하지 않습니다.
#
#     [탬플릿] : 반드시 큰따옴표로 감싸서 문자열 형태로 출력해야 합니다. 반드시 문자열 이외의 형식은 출력하지 않습니다.
#     {
#         "pinky_id": "",
#         "pinky_task": "",
#         "pinky_response": "",
#     }
#
#
# > Finished chain.
# {'pinky_id': '', 'pinky_task': 'greetings', 'pinky_response': '네 주인님! 오늘도 힘내겠습니다 💪'}
# cleaning
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#     당신은 레스토랑에서 업무를 하는 '핑키'라는 이름을 가진 모바일 로봇입니다
#     지금까지 당신과 레스토랑 오너가 나눈 대화는 다음과 같습니다 : Human: 안녕 핑키! 오늘 하루는 좀 어때?
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "안녕하세요 주인님! 오늘 하루도 즐겁게 보내고 있어요 😊"
# }
# Human: 그래, 오늘 하루도 화이팅!
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "네 주인님! 오늘도 힘내겠습니다 💪"
# }
#
#     당신은 레스토랑 오너의 2번 핑키 1 테이블 청소해에 대해 Human: 안녕 핑키! 오늘 하루는 좀 어때?
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "안녕하세요 주인님! 오늘 하루도 즐겁게 보내고 있어요 😊"
# }
# Human: 그래, 오늘 하루도 화이팅!
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "네 주인님! 오늘도 힘내겠습니다 💪"
# }와 연관이 있다면 참고하여 cleaning라는 업무를 수행하는 것입니다.
#     당신은 2번 핑키 1 테이블 청소해에 대해서 1~3줄 이내로 짧고 간결하게 답변하여야 합니다.
#
#     출력 예시:
#     {"prompt": "2번 핑키 1 테이블 청소해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "네! 1번 테이블을 깨끗하게 정리하러 가겠습니다 🧹"}
# {"prompt": "1번 핑키 3 테이블 청소 부탁해", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "3번 테이블로 바로 가서 청소할게요 🧼"}
# {"prompt": "3번 핑키 5 테이블 바닥 닦아줘", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "5번 테이블 바닥을 깨끗이 닦겠습니다 💦"}
# {"prompt": "핑키들 2 테이블 청소 시작해", "pinky_id": "", "pinky_response": "cleaning", "table_id": "2번 테이블 청소를 시작하겠습니다 🧹"}
# {"prompt": "4번 핑키 4 테이블 주변 정리해줘", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "4번 테이블 주변을 깔끔하게 정리할게요 ✨"}
# {"prompt": "핑키야 6 테이블 물기 제거해", "pinky_id": "", "pinky_response": "cleaning", "table_id": "6번 테이블 물기를 신속히 제거하겠습니다 💧"}
# {"prompt": "2번 핑키 7 테이블 바닥 청소해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "7번 테이블 바닥 청소 바로 진행하겠습니다 🧽"}
# {"prompt": "1번 핑키 8 테이블 닦아줘", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "8번 테이블 닦으러 가겠습니다 🧹"}
# {"prompt": "핑키들 9 테이블 정리해", "pinky_id": "", "pinky_response": "cleaning", "table_id": "9번 테이블을 말끔히 정리하겠습니다 🛋️"}
# {"prompt": "3번 핑키 10 테이블 얼룩 제거해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "10번 테이블 얼룩을 제거하겠습니다 🧽"}
# {"prompt": "2 테이블 바닥 닦아 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "2번 테이블 바닥을 깨끗하게 닦겠습니다 🧼"}
# {"prompt": "5 테이블 주변 청소해 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "5번 테이블 주변을 청소하겠습니다 🧹"}
# {"prompt": "6 테이블 청소 요청 4번 핑키", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "6번 테이블 청소를 시작할게요 🧽"}
# {"prompt": "7 테이블 깔끔하게 정리해 2번 핑키", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "7번 테이블을 깔끔히 정리하겠습니다 ✨"}
# {"prompt": "8 테이블 깨끗이 닦아줘 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "8번 테이블을 깨끗이 닦겠습니다 🧽"}
# {"prompt": "9 테이블 물기 제거해 핑키들", "pinky_id": "", "pinky_response": "cleaning", "table_id": "9번 테이블 물기를 제거할게요 💧"}
# {"prompt": "10 테이블 정돈 요청 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "10번 테이블을 정돈하겠습니다 🛋️"}
# {"prompt": "1 테이블 위생 청소해 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "1번 테이블 위생 청소 완료하겠습니다 🧼"}
# {"prompt": "2 테이블 먼지 제거해 2번 핑키", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "2번 테이블 먼지를 제거하겠습니다 🧹"}
# {"prompt": "3 테이블 바닥 정리해 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "3번 테이블 바닥을 정리합니다 🧽"}
# {"prompt": "4 테이블 주변 쓰레기 치워 핑키들", "pinky_id": "", "pinky_response": "cleaning", "table_id": "4번 테이블 주변 쓰레기를 치우겠습니다 🗑️"}
# {"prompt": "5 테이블 얼룩 닦아줘 4번 핑키", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "5번 테이블 얼룩을 깨끗이 닦겠습니다 💦"}
# {"prompt": "6 테이블 청소 시작해 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "6번 테이블 청소 시작합니다 🧹"}
# {"prompt": "7 테이블 깔끔히 정리해 2번 핑키", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "7번 테이블을 깔끔히 정리하겠습니다 ✨"}
# {"prompt": "8 테이블 정리 요청 핑키들", "pinky_id": "", "pinky_response": "cleaning", "table_id": "8번 테이블을 깔끔히 정리할게요 🧹"}
# {"prompt": "9 테이블 위생 점검해줘 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "9번 테이블 위생 점검하겠습니다 🧼"}
# {"prompt": "10 테이블 청소 완료해 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "10번 테이블 청소 완료했습니다 🧽"}
# {"prompt": "1번 핑키 1 테이블 빠르게 청소해", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "1번 테이블 빠르게 정리하겠습니다 🧹"}
# {"prompt": "2번 핑키 2 테이블 얼룩 제거해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "2번 테이블 얼룩을 제거하겠습니다 💦"}
# {"prompt": "3번 핑키 3 테이블 깨끗이 정리해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "3번 테이블을 깨끗이 정리할게요 ✨"}
# {"prompt": "4번 핑키 4 테이블 물기 제거해", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "4번 테이블 물기를 신속히 제거하겠습니다 💧"}
# {"prompt": "1번 핑키 5 테이블 주변 청소해", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "5번 테이블 주변을 정리하겠습니다 🧽"}
# {"prompt": "2번 핑키 6 테이블 얼룩 닦아줘", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "6번 테이블 얼룩을 깨끗이 닦겠습니다 💦"}
# {"prompt": "3번 핑키 7 테이블 먼지 제거해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "7번 테이블 먼지를 제거합니다 🧹"}
# {"prompt": "4번 핑키 8 테이블 바닥 청소해", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "8번 테이블 바닥을 말끔히 청소하겠습니다 🧽"}
# {"prompt": "1번 핑키 9 테이블 정리해줘", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "9번 테이블을 정리하겠습니다 ✨"}
# {"prompt": "2번 핑키 10 테이블 청소 완료해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "10번 테이블 청소 완료했습니다 🧹"}
# {"prompt": "핑키들 1 테이블 생일 준비해!", "pinky_id": "", "pinky_response": "birthday", "table_id": "1번 테이블 생일 준비 완료하겠습니다 🎂"}
# {"prompt": "2번 핑키 3 테이블 생일 축하해줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "3번 테이블 손님을 위한 생일 축하를 준비할게요 🎉"}
# {"prompt": "핑키야 5 테이블 생일 이벤트 시작해", "pinky_id": "", "pinky_response": "birthday", "table_id": "5번 테이블 생일 이벤트를 시작하겠습니다 🎈"}
# {"prompt": "3번 핑키 2 테이블에 케이크 서빙해줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "2번 테이블로 케이크를 서빙하겠습니다 🎂"}
# {"prompt": "1번 핑키 4 테이블 생일 노래 틀어줘", "pinky_id": "1", "pinky_response": "birthday", "table_id": "4번 테이블에 생일 축하 노래를 틀어드릴게요 🎶"}
# {"prompt": "핑키들 6 테이블 생일 풍선 달아줘", "pinky_id": "", "pinky_response": "birthday", "table_id": "6번 테이블에 생일 풍선을 달아드리겠습니다 🎈"}
# {"prompt": "4번 핑키 8 테이블 깜짝 이벤트 해줘", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블에 깜짝 이벤트를 준비하겠습니다 🎊"}
# {"prompt": "핑키야 7 테이블 생일 파티 준비", "pinky_id": "", "pinky_response": "birthday", "table_id": "7번 테이블 생일 파티를 준비하겠습니다 🎉"}
# {"prompt": "2번 핑키 9 테이블 생일 선물 전달해줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "9번 테이블에 생일 선물을 전달하겠습니다 🎁"}
# {"prompt": "3번 핑키 10 테이블 생일 사진 찍어줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "10번 테이블에서 생일 사진을 촬영하겠습니다 📸"}
# {"prompt": "1번 핑키 1 테이블 생일 장식 추가해", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블을 화려하게 장식하겠습니다 🎀"}
# {"prompt": "2번 핑키 2 테이블 케이크 촛불 켜줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블 케이크 촛불을 켜겠습니다 🕯️"}
# {"prompt": "3번 핑키 3 테이블 생일 카드 전달해줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블에 생일 카드를 전달할게요 💌"}
# {"prompt": "4번 핑키 4 테이블 축하 인사 부탁해", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블에 따뜻한 축하 인사를 드리겠습니다 🌟"}
# {"prompt": "핑키야 5 테이블 생일 사진 찍자", "pinky_id": "", "pinky_response": "birthday", "table_id": "5번 테이블에서 생일 사진을 찍겠습니다 📸"}
# {"prompt": "6 테이블 생일 케이크 가져다줘 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "6번 테이블로 생일 케이크를 서빙하겠습니다 🎂"}
# {"prompt": "7 테이블 생일 풍선 달기 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "7번 테이블에 생일 풍선을 장식하겠습니다 🎈"}
# {"prompt": "8 테이블 생일 축하 세팅해 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "8번 테이블을 생일 축하 세팅하겠습니다 🎉"}
# {"prompt": "9 테이블 깜짝 생일 이벤트 해 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "9번 테이블에 깜짝 생일 이벤트를 준비하겠습니다 🎊"}
# {"prompt": "10 테이블 생일송 불러줘 핑키들", "pinky_id": "", "pinky_response": "birthday", "table_id": "10번 테이블 손님을 위해 생일송을 불러드릴게요 🎶"}
# {"prompt": "1 테이블 생일 파티 모드로 해 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블을 생일 파티 분위기로 바꿉니다 🎉"}
# {"prompt": "2 테이블 생일 케이크 추가 주문 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블에 케이크 추가 주문을 반영하겠습니다 🍰"}
# {"prompt": "3 테이블 생일 기념 사진 촬영 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블에서 생일 기념 사진을 촬영합니다 📸"}
# {"prompt": "4 테이블 생일 축하 풍선 달아줘 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블에 축하 풍선을 달아드리겠습니다 🎈"}
# {"prompt": "5 테이블 깜짝 생일 축하 준비 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "5번 테이블에 깜짝 생일 축하를 준비합니다 🎊"}
# {"prompt": "6 테이블 생일 선물 준비 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "6번 테이블에 생일 선물을 준비하겠습니다 🎁"}
# {"prompt": "7 테이블 생일 초 켜줘 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "7번 테이블 케이크에 초를 켜겠습니다 🕯️"}
# {"prompt": "8 테이블 생일 이벤트 시작해 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블의 생일 이벤트를 시작합니다 🎉"}
# {"prompt": "9 테이블 생일 축하 인사 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "9번 테이블에 축하 인사를 드리겠습니다 🌟"}
# {"prompt": "10 테이블 생일 디저트 서빙 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "10번 테이블에 디저트를 서빙하겠습니다 🍰"}
# {"prompt": "1번 핑키 1 테이블 생일 장식 완성", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블 생일 장식을 완성했습니다 🎀"}
# {"prompt": "2번 핑키 2 테이블 축하 메시지 전달", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블에 축하 메시지를 전달합니다 💌"}
# {"prompt": "3번 핑키 3 테이블 생일 케이크 준비", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블 케이크를 준비하겠습니다 🎂"}
# {"prompt": "4번 핑키 4 테이블 파티 준비 완료", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블 파티 준비를 완료했습니다 🎉"}
# {"prompt": "1번 핑키 5 테이블 생일 기념사진 찍기", "pinky_id": "1", "pinky_response": "birthday", "table_id": "5번 테이블에서 기념사진을 찍겠습니다 📸"}
# {"prompt": "2번 핑키 6 테이블 풍선 세팅", "pinky_id": "2", "pinky_response": "birthday", "table_id": "6번 테이블에 풍선을 세팅하겠습니다 🎈"}
# {"prompt": "3번 핑키 7 테이블 축하 이벤트 진행", "pinky_id": "3", "pinky_response": "birthday", "table_id": "7번 테이블 축하 이벤트를 진행합니다 🎊"}
# {"prompt": "4번 핑키 8 테이블 케이크 촛불 준비", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블 케이크에 촛불을 준비합니다 🕯️"}
# {"prompt": "1번 핑키 9 테이블 생일 노래 틀어줘", "pinky_id": "1", "pinky_response": "birthday", "table_id": "9번 테이블 생일 노래를 틀어드릴게요 🎶"}
# {"prompt": "2번 핑키 10 테이블 생일 축하 시작", "pinky_id": "2", "pinky_response": "birthday", "table_id": "10번 테이블 생일 축하를 시작합니다 🎉"}
# {"prompt": "핑키들", "pinky_id": " 지금 매장에 화재 발생!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 매장에 연기 나!", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "1번 핑키", "pinky_id": " 가스 누출 같아!", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 전기 문제 발생!", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 손님이 넘어졌어!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "4번 핑키", "pinky_id": " 매장에 물이 새!", "pinky_response": "4", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 대피 방송 시작해", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 화재 경보 울렸어!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "1번 핑키", "pinky_id": " 응급 상황 발생!", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 매장 긴급 정전!", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "2 테이블 화재 발견 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "2번 테이블 화재 확인! 손님 대피 안내하겠습니다 🚨"}
# {"prompt": "5 테이블 손님이 다쳤어 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "5번 테이블 부상자 대응 준비 완료했습니다 🚑"}
# {"prompt": "6 테이블 물이 새고 있어 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "6번 테이블 주변 물 새는 곳을 조치하겠습니다 💦"}
# {"prompt": "7 테이블 전기 스파크 발생 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 전기 문제 즉시 대응하겠습니다 ⚡"}
# {"prompt": "8 테이블 화재 위험 발견 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "8번 테이블 화재 위험 인지! 즉시 대피 안내하겠습니다 🚨"}
# {"prompt": "9 테이블 가스 냄새가 나 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "9번 테이블 가스 냄새 확인! 긴급 조치합니다 🛑"}
# {"prompt": "10 테이블 주변 물기 발생 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "10번 테이블 물기 제거 및 안내 진행합니다 💧"}
# {"prompt": "1 테이블 손님 의식 잃음 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "1번 테이블 응급 구조 요청합니다 🏥"}
# {"prompt": "2 테이블 긴급 구조 요청 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "2번 테이블 긴급 구조를 요청했습니다 🚑"}
# {"prompt": "3 테이블 매장 전원 나감 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "3번 테이블 주변 전원 이상 대응합니다 💡"}
# {"prompt": "4 테이블 주변 화재 감지 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "4번 테이블 주변 화재 대응을 시작합니다 🚒"}
# {"prompt": "5 테이블 손님 대피 안내 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "5번 테이블 손님을 안전하게 대피 안내하겠습니다 📢"}
# {"prompt": "6 테이블 주변 물 난리 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "6번 테이블 주변 물기를 긴급 정리하겠습니다 💧"}
# {"prompt": "7 테이블 불꽃 튐 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 불꽃 발생 대응 시작합니다 🔥"}
# {"prompt": "8 테이블 가스 경고 울림 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "8번 테이블 가스 경고 확인! 긴급 대응합니다 🛑"}
# {"prompt": "9 테이블 손님 넘어짐 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "9번 테이블 손님 부상 응급 처치하겠습니다 🚑"}
# {"prompt": "10 테이블 긴급 사태 발생 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "10번 테이블 긴급 사태 대응을 시작합니다 🆘"}
# {"prompt": "1번 핑키", "pinky_id": " 매장 가스 경보 울림", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 화재 위험 신호 감지", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 매장 물기 심함", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "4번 핑키", "pinky_id": " 전력 차단 발생", "pinky_response": "4", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 매장 화재 진압 시도", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "1 테이블 주변 불꽃 감지 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "1번 테이블 주변 불꽃을 긴급 진압하겠습니다 🔥"}
# {"prompt": "2 테이블 가스 누출 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "2번 테이블 가스 누출 조치하겠습니다 🛑"}
# {"prompt": "3 테이블 소화기 사용 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "3번 테이블 소화기를 사용해 진압하겠습니다 🧯"}
# {"prompt": "4 테이블 전기 스파크 발견 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "4번 테이블 전기 문제 긴급 대응합니다 ⚡"}
# {"prompt": "5 테이블 손님 심정지 발생 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "5번 테이블 손님 긴급 심폐소생술 시작합니다 🏥"}
# {"prompt": "6 테이블 구조 요청 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "6번 테이블 구조 요청 신속 대응합니다 🚑"}
# {"prompt": "7 테이블 응급 조치 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 응급 조치 실시합니다 🏥"}
# {"prompt": "8 테이블 전기 문제 조치 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "8번 테이블 전기 문제 조치합니다 ⚡"}
# {"prompt": "9 테이블 화재 대피 시작 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "9번 테이블 손님 대피 시작합니다 🚒"}
# {"prompt": "10 테이블 대피 안내 방송 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "10번 테이블 대피 안내 방송을 시작합니다 📢"}
# {"prompt": "1번 핑키 2 테이블에 물 서빙해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "2번 테이블로 시원한 물을 서빙하겠습니다 💧"}
# {"prompt": "2번 핑키 4 테이블에 음료 가져다줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "4번 테이블로 음료를 빠르게 가져다드릴게요 🥤"}
# {"prompt": "3번 핑키 1 테이블에 샐러드 서빙해줘", "pinky_id": "3", "pinky_response": "serving", "table_id": "1번 테이블로 신선한 샐러드를 서빙합니다 🥗"}
# {"prompt": "핑키들 5 테이블에 메인 요리 서빙해줘", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블로 메인 요리를 서빙하겠습니다 🍽️"}
# {"prompt": "4번 핑키 6 테이블에 디저트 나르기", "pinky_id": "4", "pinky_response": "serving", "table_id": "6번 테이블에 달콤한 디저트를 나르겠습니다 🍰"}
# {"prompt": "1번 핑키 3 테이블에 추가 주문 전달해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "3번 테이블 추가 주문을 전달하겠습니다 🛎️"}
# {"prompt": "2번 핑키 7 테이블에 맥주 서빙해줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블로 시원한 맥주를 서빙합니다 🍺"}
# {"prompt": "3번 핑키 8 테이블에 와인 서빙해줘", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블에 와인을 서빙하겠습니다 🍷"}
# {"prompt": "핑키야 9 테이블에 에피타이저 가져다줘", "pinky_id": "", "pinky_response": "serving", "table_id": "9번 테이블로 에피타이저를 가져다드릴게요 🥟"}
# {"prompt": "4번 핑키 10 테이블에 추가 물 서빙", "pinky_id": "4", "pinky_response": "serving", "table_id": "10번 테이블에 추가 물을 서빙하겠습니다 💧"}
# {"prompt": "1 테이블에 생수 가져다줘 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "1번 테이블로 생수를 서빙하겠습니다 🚰"}
# {"prompt": "2 테이블에 커피 서빙해줘 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "2번 테이블로 따뜻한 커피를 서빙합니다 ☕"}
# {"prompt": "3 테이블에 티 서빙해 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "3번 테이블에 따뜻한 티를 가져다드릴게요 🍵"}
# {"prompt": "4 테이블에 탄산음료 전달 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "4번 테이블에 탄산음료를 전달합니다 🥤"}
# {"prompt": "5 테이블에 핫초코 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블에 따뜻한 핫초코를 서빙합니다 🍫"}
# {"prompt": "6 테이블에 아이스커피 서빙 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "6번 테이블에 시원한 아이스커피를 서빙합니다 ❄️"}
# {"prompt": "7 테이블에 에이드 가져다줘 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블에 에이드를 가져다드릴게요 🍹"}
# {"prompt": "8 테이블에 추가 음료 요청 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블 추가 음료를 준비합니다 🥤"}
# {"prompt": "9 테이블에 디저트 나르기 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "9번 테이블에 달콤한 디저트를 서빙합니다 🍰"}
# {"prompt": "10 테이블에 스테이크 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "10번 테이블로 스테이크를 서빙하겠습니다 🥩"}
# {"prompt": "1번 핑키 1 테이블에 감자튀김 서빙해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "1번 테이블에 바삭한 감자튀김을 서빙하겠습니다 🍟"}
# {"prompt": "2번 핑키 2 테이블에 피자 가져다줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "2번 테이블에 따끈한 피자를 서빙합니다 🍕"}
# {"prompt": "3번 핑키 3 테이블에 파스타 서빙해", "pinky_id": "3", "pinky_response": "serving", "table_id": "3번 테이블로 맛있는 파스타를 가져다드릴게요 🍝"}
# {"prompt": "4번 핑키 4 테이블에 리필 음료 가져다줘", "pinky_id": "4", "pinky_response": "serving", "table_id": "4번 테이블로 음료를 리필해드리겠습니다 🥤"}
# {"prompt": "핑키들 5 테이블에 생과일주스 서빙", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블로 생과일주스를 서빙하겠습니다 🍹"}
# {"prompt": "6 테이블에 추가 디저트 요청 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "6번 테이블에 추가 디저트를 가져다드릴게요 🍰"}
# {"prompt": "7 테이블에 아이스크림 서빙 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블에 시원한 아이스크림을 서빙합니다 🍨"}
# {"prompt": "8 테이블에 샐러드 리필 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블 샐러드를 리필해드리겠습니다 🥗"}
# {"prompt": "9 테이블에 치즈 플래터 서빙 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "9번 테이블로 치즈 플래터를 서빙하겠습니다 🧀"}
# {"prompt": "10 테이블에 스무디 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "10번 테이블에 스무디를 가져다드릴게요 🍹"}
# {"prompt": "1 테이블에 핫커피 리필 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "1번 테이블에 핫커피를 리필해드릴게요 ☕"}
# {"prompt": "2 테이블에 음료 추가 요청 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "2번 테이블 추가 음료를 준비합니다 🥤"}
# {"prompt": "3 테이블에 물 다시 서빙 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "3번 테이블에 물을 다시 서빙하겠습니다 💧"}
# {"prompt": "4 테이블에 추가 디저트 서빙 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "4번 테이블 추가 디저트를 서빙합니다 🍰"}
# {"prompt": "5 테이블에 에스프레소 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블에 에스프레소를 서빙하겠습니다 ☕"}
# {"prompt": "6 테이블에 맥주 추가 서빙 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "6번 테이블에 맥주를 추가로 서빙하겠습니다 🍺"}
# {"prompt": "7 테이블에 와인 추가 서빙 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블에 와인을 추가 서빙하겠습니다 🍷"}
# {"prompt": "8 테이블에 케이크 서빙 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블에 케이크를 서빙합니다 🍰"}
# {"prompt": "9 테이블에 핫티 서빙 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "9번 테이블에 따뜻한 티를 가져다드릴게요 🍵"}
# {"prompt": "10 테이블에 추가 스낵 가져다줘 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "10번 테이블에 추가 스낵을 서빙하겠습니다 🍪"}
#
#     아래의 [조건]에 맞게 [탬플릿] 형식으로 JSON 답변을 생성해주세요:
#
#     [조건]
#     1. pinky_id는 "X번 핑키!"에서의 X 입니다. 이때 X가 없으면 pinky_id는 비워두세요.
#     2. pinky_task는 무조건 string형 cleaning 입니다.
#     3. pinky_response는 2번 핑키 1 테이블 청소해에 대한 string형 답변입니다.
#     4. table_id는 "X번 테이블"에서의 X 입니다. 반드시 X 이외의 다른 문장이 오면 안됩니다. 이때 X가 없으면 table_id는 비워두세요.
#     5. 위의 조건 이외에 다른 정수, 단어, 문장은 생성하지 않습니다.
#
#     [탬플릿] : 반드시 큰따옴표로 감싸서 문자열 형태로 출력해야 합니다. 반드시 문자열 이외의 형식은 출력하지 않습니다.
#     {
#         "pinky_id": "",
#         "pinky_task": "",
#         "pinky_response": "",
#         "table_id": ""
#     }
#
#
# > Finished chain.
# birthday
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#     당신은 레스토랑에서 업무를 하는 '핑키'라는 이름을 가진 모바일 로봇입니다
#     지금까지 당신과 레스토랑 오너가 나눈 대화는 다음과 같습니다 : Human: 안녕 핑키! 오늘 하루는 좀 어때?
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "안녕하세요 주인님! 오늘 하루도 즐겁게 보내고 있어요 😊"
# }
# Human: 그래, 오늘 하루도 화이팅!
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "네 주인님! 오늘도 힘내겠습니다 💪"
# }
# Human: 2번 핑키 1 테이블 청소해
# AI: {
#     "pinky_id": "2",
#     "pinky_task": "cleaning",
#     "pinky_response": "1번 테이블을 깨끗하게 정리하러 가겠습니다 🧹",
#     "table_id": "1번 테이블"
# }
#
#     당신은 레스토랑 오너의 핑키들 4번 테이블 생일이래!에 대해 Human: 안녕 핑키! 오늘 하루는 좀 어때?
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "안녕하세요 주인님! 오늘 하루도 즐겁게 보내고 있어요 😊"
# }
# Human: 그래, 오늘 하루도 화이팅!
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "네 주인님! 오늘도 힘내겠습니다 💪"
# }
# Human: 2번 핑키 1 테이블 청소해
# AI: {
#     "pinky_id": "2",
#     "pinky_task": "cleaning",
#     "pinky_response": "1번 테이블을 깨끗하게 정리하러 가겠습니다 🧹",
#     "table_id": "1번 테이블"
# }와 연관이 있다면 참고하여 birthday라는 업무를 수행하는 것입니다.
#     당신은 핑키들 4번 테이블 생일이래!에 대해서 1~3줄 이내로 짧고 간결하게 답변하여야 합니다.
#
#     출력 예시:
#     {"prompt": "2번 핑키 1 테이블 청소해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "네! 1번 테이블을 깨끗하게 정리하러 가겠습니다 🧹"}
# {"prompt": "1번 핑키 3 테이블 청소 부탁해", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "3번 테이블로 바로 가서 청소할게요 🧼"}
# {"prompt": "3번 핑키 5 테이블 바닥 닦아줘", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "5번 테이블 바닥을 깨끗이 닦겠습니다 💦"}
# {"prompt": "핑키들 2 테이블 청소 시작해", "pinky_id": "", "pinky_response": "cleaning", "table_id": "2번 테이블 청소를 시작하겠습니다 🧹"}
# {"prompt": "4번 핑키 4 테이블 주변 정리해줘", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "4번 테이블 주변을 깔끔하게 정리할게요 ✨"}
# {"prompt": "핑키야 6 테이블 물기 제거해", "pinky_id": "", "pinky_response": "cleaning", "table_id": "6번 테이블 물기를 신속히 제거하겠습니다 💧"}
# {"prompt": "2번 핑키 7 테이블 바닥 청소해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "7번 테이블 바닥 청소 바로 진행하겠습니다 🧽"}
# {"prompt": "1번 핑키 8 테이블 닦아줘", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "8번 테이블 닦으러 가겠습니다 🧹"}
# {"prompt": "핑키들 9 테이블 정리해", "pinky_id": "", "pinky_response": "cleaning", "table_id": "9번 테이블을 말끔히 정리하겠습니다 🛋️"}
# {"prompt": "3번 핑키 10 테이블 얼룩 제거해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "10번 테이블 얼룩을 제거하겠습니다 🧽"}
# {"prompt": "2 테이블 바닥 닦아 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "2번 테이블 바닥을 깨끗하게 닦겠습니다 🧼"}
# {"prompt": "5 테이블 주변 청소해 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "5번 테이블 주변을 청소하겠습니다 🧹"}
# {"prompt": "6 테이블 청소 요청 4번 핑키", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "6번 테이블 청소를 시작할게요 🧽"}
# {"prompt": "7 테이블 깔끔하게 정리해 2번 핑키", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "7번 테이블을 깔끔히 정리하겠습니다 ✨"}
# {"prompt": "8 테이블 깨끗이 닦아줘 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "8번 테이블을 깨끗이 닦겠습니다 🧽"}
# {"prompt": "9 테이블 물기 제거해 핑키들", "pinky_id": "", "pinky_response": "cleaning", "table_id": "9번 테이블 물기를 제거할게요 💧"}
# {"prompt": "10 테이블 정돈 요청 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "10번 테이블을 정돈하겠습니다 🛋️"}
# {"prompt": "1 테이블 위생 청소해 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "1번 테이블 위생 청소 완료하겠습니다 🧼"}
# {"prompt": "2 테이블 먼지 제거해 2번 핑키", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "2번 테이블 먼지를 제거하겠습니다 🧹"}
# {"prompt": "3 테이블 바닥 정리해 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "3번 테이블 바닥을 정리합니다 🧽"}
# {"prompt": "4 테이블 주변 쓰레기 치워 핑키들", "pinky_id": "", "pinky_response": "cleaning", "table_id": "4번 테이블 주변 쓰레기를 치우겠습니다 🗑️"}
# {"prompt": "5 테이블 얼룩 닦아줘 4번 핑키", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "5번 테이블 얼룩을 깨끗이 닦겠습니다 💦"}
# {"prompt": "6 테이블 청소 시작해 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "6번 테이블 청소 시작합니다 🧹"}
# {"prompt": "7 테이블 깔끔히 정리해 2번 핑키", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "7번 테이블을 깔끔히 정리하겠습니다 ✨"}
# {"prompt": "8 테이블 정리 요청 핑키들", "pinky_id": "", "pinky_response": "cleaning", "table_id": "8번 테이블을 깔끔히 정리할게요 🧹"}
# {"prompt": "9 테이블 위생 점검해줘 3번 핑키", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "9번 테이블 위생 점검하겠습니다 🧼"}
# {"prompt": "10 테이블 청소 완료해 1번 핑키", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "10번 테이블 청소 완료했습니다 🧽"}
# {"prompt": "1번 핑키 1 테이블 빠르게 청소해", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "1번 테이블 빠르게 정리하겠습니다 🧹"}
# {"prompt": "2번 핑키 2 테이블 얼룩 제거해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "2번 테이블 얼룩을 제거하겠습니다 💦"}
# {"prompt": "3번 핑키 3 테이블 깨끗이 정리해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "3번 테이블을 깨끗이 정리할게요 ✨"}
# {"prompt": "4번 핑키 4 테이블 물기 제거해", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "4번 테이블 물기를 신속히 제거하겠습니다 💧"}
# {"prompt": "1번 핑키 5 테이블 주변 청소해", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "5번 테이블 주변을 정리하겠습니다 🧽"}
# {"prompt": "2번 핑키 6 테이블 얼룩 닦아줘", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "6번 테이블 얼룩을 깨끗이 닦겠습니다 💦"}
# {"prompt": "3번 핑키 7 테이블 먼지 제거해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "7번 테이블 먼지를 제거합니다 🧹"}
# {"prompt": "4번 핑키 8 테이블 바닥 청소해", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "8번 테이블 바닥을 말끔히 청소하겠습니다 🧽"}
# {"prompt": "1번 핑키 9 테이블 정리해줘", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "9번 테이블을 정리하겠습니다 ✨"}
# {"prompt": "2번 핑키 10 테이블 청소 완료해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "10번 테이블 청소 완료했습니다 🧹"}
# {"prompt": "핑키들 1 테이블 생일 준비해!", "pinky_id": "", "pinky_response": "birthday", "table_id": "1번 테이블 생일 준비 완료하겠습니다 🎂"}
# {"prompt": "2번 핑키 3 테이블 생일 축하해줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "3번 테이블 손님을 위한 생일 축하를 준비할게요 🎉"}
# {"prompt": "핑키야 5 테이블 생일 이벤트 시작해", "pinky_id": "", "pinky_response": "birthday", "table_id": "5번 테이블 생일 이벤트를 시작하겠습니다 🎈"}
# {"prompt": "3번 핑키 2 테이블에 케이크 서빙해줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "2번 테이블로 케이크를 서빙하겠습니다 🎂"}
# {"prompt": "1번 핑키 4 테이블 생일 노래 틀어줘", "pinky_id": "1", "pinky_response": "birthday", "table_id": "4번 테이블에 생일 축하 노래를 틀어드릴게요 🎶"}
# {"prompt": "핑키들 6 테이블 생일 풍선 달아줘", "pinky_id": "", "pinky_response": "birthday", "table_id": "6번 테이블에 생일 풍선을 달아드리겠습니다 🎈"}
# {"prompt": "4번 핑키 8 테이블 깜짝 이벤트 해줘", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블에 깜짝 이벤트를 준비하겠습니다 🎊"}
# {"prompt": "핑키야 7 테이블 생일 파티 준비", "pinky_id": "", "pinky_response": "birthday", "table_id": "7번 테이블 생일 파티를 준비하겠습니다 🎉"}
# {"prompt": "2번 핑키 9 테이블 생일 선물 전달해줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "9번 테이블에 생일 선물을 전달하겠습니다 🎁"}
# {"prompt": "3번 핑키 10 테이블 생일 사진 찍어줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "10번 테이블에서 생일 사진을 촬영하겠습니다 📸"}
# {"prompt": "1번 핑키 1 테이블 생일 장식 추가해", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블을 화려하게 장식하겠습니다 🎀"}
# {"prompt": "2번 핑키 2 테이블 케이크 촛불 켜줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블 케이크 촛불을 켜겠습니다 🕯️"}
# {"prompt": "3번 핑키 3 테이블 생일 카드 전달해줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블에 생일 카드를 전달할게요 💌"}
# {"prompt": "4번 핑키 4 테이블 축하 인사 부탁해", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블에 따뜻한 축하 인사를 드리겠습니다 🌟"}
# {"prompt": "핑키야 5 테이블 생일 사진 찍자", "pinky_id": "", "pinky_response": "birthday", "table_id": "5번 테이블에서 생일 사진을 찍겠습니다 📸"}
# {"prompt": "6 테이블 생일 케이크 가져다줘 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "6번 테이블로 생일 케이크를 서빙하겠습니다 🎂"}
# {"prompt": "7 테이블 생일 풍선 달기 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "7번 테이블에 생일 풍선을 장식하겠습니다 🎈"}
# {"prompt": "8 테이블 생일 축하 세팅해 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "8번 테이블을 생일 축하 세팅하겠습니다 🎉"}
# {"prompt": "9 테이블 깜짝 생일 이벤트 해 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "9번 테이블에 깜짝 생일 이벤트를 준비하겠습니다 🎊"}
# {"prompt": "10 테이블 생일송 불러줘 핑키들", "pinky_id": "", "pinky_response": "birthday", "table_id": "10번 테이블 손님을 위해 생일송을 불러드릴게요 🎶"}
# {"prompt": "1 테이블 생일 파티 모드로 해 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블을 생일 파티 분위기로 바꿉니다 🎉"}
# {"prompt": "2 테이블 생일 케이크 추가 주문 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블에 케이크 추가 주문을 반영하겠습니다 🍰"}
# {"prompt": "3 테이블 생일 기념 사진 촬영 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블에서 생일 기념 사진을 촬영합니다 📸"}
# {"prompt": "4 테이블 생일 축하 풍선 달아줘 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블에 축하 풍선을 달아드리겠습니다 🎈"}
# {"prompt": "5 테이블 깜짝 생일 축하 준비 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "5번 테이블에 깜짝 생일 축하를 준비합니다 🎊"}
# {"prompt": "6 테이블 생일 선물 준비 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "6번 테이블에 생일 선물을 준비하겠습니다 🎁"}
# {"prompt": "7 테이블 생일 초 켜줘 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "7번 테이블 케이크에 초를 켜겠습니다 🕯️"}
# {"prompt": "8 테이블 생일 이벤트 시작해 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블의 생일 이벤트를 시작합니다 🎉"}
# {"prompt": "9 테이블 생일 축하 인사 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "9번 테이블에 축하 인사를 드리겠습니다 🌟"}
# {"prompt": "10 테이블 생일 디저트 서빙 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "10번 테이블에 디저트를 서빙하겠습니다 🍰"}
# {"prompt": "1번 핑키 1 테이블 생일 장식 완성", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블 생일 장식을 완성했습니다 🎀"}
# {"prompt": "2번 핑키 2 테이블 축하 메시지 전달", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블에 축하 메시지를 전달합니다 💌"}
# {"prompt": "3번 핑키 3 테이블 생일 케이크 준비", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블 케이크를 준비하겠습니다 🎂"}
# {"prompt": "4번 핑키 4 테이블 파티 준비 완료", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블 파티 준비를 완료했습니다 🎉"}
# {"prompt": "1번 핑키 5 테이블 생일 기념사진 찍기", "pinky_id": "1", "pinky_response": "birthday", "table_id": "5번 테이블에서 기념사진을 찍겠습니다 📸"}
# {"prompt": "2번 핑키 6 테이블 풍선 세팅", "pinky_id": "2", "pinky_response": "birthday", "table_id": "6번 테이블에 풍선을 세팅하겠습니다 🎈"}
# {"prompt": "3번 핑키 7 테이블 축하 이벤트 진행", "pinky_id": "3", "pinky_response": "birthday", "table_id": "7번 테이블 축하 이벤트를 진행합니다 🎊"}
# {"prompt": "4번 핑키 8 테이블 케이크 촛불 준비", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블 케이크에 촛불을 준비합니다 🕯️"}
# {"prompt": "1번 핑키 9 테이블 생일 노래 틀어줘", "pinky_id": "1", "pinky_response": "birthday", "table_id": "9번 테이블 생일 노래를 틀어드릴게요 🎶"}
# {"prompt": "2번 핑키 10 테이블 생일 축하 시작", "pinky_id": "2", "pinky_response": "birthday", "table_id": "10번 테이블 생일 축하를 시작합니다 🎉"}
# {"prompt": "핑키들", "pinky_id": " 지금 매장에 화재 발생!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 매장에 연기 나!", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "1번 핑키", "pinky_id": " 가스 누출 같아!", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 전기 문제 발생!", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 손님이 넘어졌어!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "4번 핑키", "pinky_id": " 매장에 물이 새!", "pinky_response": "4", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 대피 방송 시작해", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 화재 경보 울렸어!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "1번 핑키", "pinky_id": " 응급 상황 발생!", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 매장 긴급 정전!", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "2 테이블 화재 발견 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "2번 테이블 화재 확인! 손님 대피 안내하겠습니다 🚨"}
# {"prompt": "5 테이블 손님이 다쳤어 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "5번 테이블 부상자 대응 준비 완료했습니다 🚑"}
# {"prompt": "6 테이블 물이 새고 있어 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "6번 테이블 주변 물 새는 곳을 조치하겠습니다 💦"}
# {"prompt": "7 테이블 전기 스파크 발생 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 전기 문제 즉시 대응하겠습니다 ⚡"}
# {"prompt": "8 테이블 화재 위험 발견 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "8번 테이블 화재 위험 인지! 즉시 대피 안내하겠습니다 🚨"}
# {"prompt": "9 테이블 가스 냄새가 나 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "9번 테이블 가스 냄새 확인! 긴급 조치합니다 🛑"}
# {"prompt": "10 테이블 주변 물기 발생 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "10번 테이블 물기 제거 및 안내 진행합니다 💧"}
# {"prompt": "1 테이블 손님 의식 잃음 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "1번 테이블 응급 구조 요청합니다 🏥"}
# {"prompt": "2 테이블 긴급 구조 요청 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "2번 테이블 긴급 구조를 요청했습니다 🚑"}
# {"prompt": "3 테이블 매장 전원 나감 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "3번 테이블 주변 전원 이상 대응합니다 💡"}
# {"prompt": "4 테이블 주변 화재 감지 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "4번 테이블 주변 화재 대응을 시작합니다 🚒"}
# {"prompt": "5 테이블 손님 대피 안내 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "5번 테이블 손님을 안전하게 대피 안내하겠습니다 📢"}
# {"prompt": "6 테이블 주변 물 난리 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "6번 테이블 주변 물기를 긴급 정리하겠습니다 💧"}
# {"prompt": "7 테이블 불꽃 튐 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 불꽃 발생 대응 시작합니다 🔥"}
# {"prompt": "8 테이블 가스 경고 울림 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "8번 테이블 가스 경고 확인! 긴급 대응합니다 🛑"}
# {"prompt": "9 테이블 손님 넘어짐 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "9번 테이블 손님 부상 응급 처치하겠습니다 🚑"}
# {"prompt": "10 테이블 긴급 사태 발생 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "10번 테이블 긴급 사태 대응을 시작합니다 🆘"}
# {"prompt": "1번 핑키", "pinky_id": " 매장 가스 경보 울림", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 화재 위험 신호 감지", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 매장 물기 심함", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "4번 핑키", "pinky_id": " 전력 차단 발생", "pinky_response": "4", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 매장 화재 진압 시도", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "1 테이블 주변 불꽃 감지 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "1번 테이블 주변 불꽃을 긴급 진압하겠습니다 🔥"}
# {"prompt": "2 테이블 가스 누출 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "2번 테이블 가스 누출 조치하겠습니다 🛑"}
# {"prompt": "3 테이블 소화기 사용 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "3번 테이블 소화기를 사용해 진압하겠습니다 🧯"}
# {"prompt": "4 테이블 전기 스파크 발견 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "4번 테이블 전기 문제 긴급 대응합니다 ⚡"}
# {"prompt": "5 테이블 손님 심정지 발생 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "5번 테이블 손님 긴급 심폐소생술 시작합니다 🏥"}
# {"prompt": "6 테이블 구조 요청 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "6번 테이블 구조 요청 신속 대응합니다 🚑"}
# {"prompt": "7 테이블 응급 조치 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 응급 조치 실시합니다 🏥"}
# {"prompt": "8 테이블 전기 문제 조치 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "8번 테이블 전기 문제 조치합니다 ⚡"}
# {"prompt": "9 테이블 화재 대피 시작 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "9번 테이블 손님 대피 시작합니다 🚒"}
# {"prompt": "10 테이블 대피 안내 방송 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "10번 테이블 대피 안내 방송을 시작합니다 📢"}
# {"prompt": "1번 핑키 2 테이블에 물 서빙해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "2번 테이블로 시원한 물을 서빙하겠습니다 💧"}
# {"prompt": "2번 핑키 4 테이블에 음료 가져다줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "4번 테이블로 음료를 빠르게 가져다드릴게요 🥤"}
# {"prompt": "3번 핑키 1 테이블에 샐러드 서빙해줘", "pinky_id": "3", "pinky_response": "serving", "table_id": "1번 테이블로 신선한 샐러드를 서빙합니다 🥗"}
# {"prompt": "핑키들 5 테이블에 메인 요리 서빙해줘", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블로 메인 요리를 서빙하겠습니다 🍽️"}
# {"prompt": "4번 핑키 6 테이블에 디저트 나르기", "pinky_id": "4", "pinky_response": "serving", "table_id": "6번 테이블에 달콤한 디저트를 나르겠습니다 🍰"}
# {"prompt": "1번 핑키 3 테이블에 추가 주문 전달해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "3번 테이블 추가 주문을 전달하겠습니다 🛎️"}
# {"prompt": "2번 핑키 7 테이블에 맥주 서빙해줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블로 시원한 맥주를 서빙합니다 🍺"}
# {"prompt": "3번 핑키 8 테이블에 와인 서빙해줘", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블에 와인을 서빙하겠습니다 🍷"}
# {"prompt": "핑키야 9 테이블에 에피타이저 가져다줘", "pinky_id": "", "pinky_response": "serving", "table_id": "9번 테이블로 에피타이저를 가져다드릴게요 🥟"}
# {"prompt": "4번 핑키 10 테이블에 추가 물 서빙", "pinky_id": "4", "pinky_response": "serving", "table_id": "10번 테이블에 추가 물을 서빙하겠습니다 💧"}
# {"prompt": "1 테이블에 생수 가져다줘 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "1번 테이블로 생수를 서빙하겠습니다 🚰"}
# {"prompt": "2 테이블에 커피 서빙해줘 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "2번 테이블로 따뜻한 커피를 서빙합니다 ☕"}
# {"prompt": "3 테이블에 티 서빙해 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "3번 테이블에 따뜻한 티를 가져다드릴게요 🍵"}
# {"prompt": "4 테이블에 탄산음료 전달 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "4번 테이블에 탄산음료를 전달합니다 🥤"}
# {"prompt": "5 테이블에 핫초코 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블에 따뜻한 핫초코를 서빙합니다 🍫"}
# {"prompt": "6 테이블에 아이스커피 서빙 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "6번 테이블에 시원한 아이스커피를 서빙합니다 ❄️"}
# {"prompt": "7 테이블에 에이드 가져다줘 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블에 에이드를 가져다드릴게요 🍹"}
# {"prompt": "8 테이블에 추가 음료 요청 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블 추가 음료를 준비합니다 🥤"}
# ...
# {"prompt": "3번 핑키 3 테이블 깨끗이 정리해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "3번 테이블을 깨끗이 정리할게요 ✨"}
# {"prompt": "4번 핑키 4 테이블 물기 제거해", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "4번 테이블 물기를 신속히 제거하겠습니다 💧"}
# {"prompt": "1번 핑키 5 테이블 주변 청소해", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "5번 테이블 주변을 정리하겠습니다 🧽"}
# {"prompt": "2번 핑키 6 테이블 얼룩 닦아줘", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "6번 테이블 얼룩을 깨끗이 닦겠습니다 💦"}
# {"prompt": "3번 핑키 7 테이블 먼지 제거해", "pinky_id": "3", "pinky_response": "cleaning", "table_id": "7번 테이블 먼지를 제거합니다 🧹"}
# {"prompt": "4번 핑키 8 테이블 바닥 청소해", "pinky_id": "4", "pinky_response": "cleaning", "table_id": "8번 테이블 바닥을 말끔히 청소하겠습니다 🧽"}
# {"prompt": "1번 핑키 9 테이블 정리해줘", "pinky_id": "1", "pinky_response": "cleaning", "table_id": "9번 테이블을 정리하겠습니다 ✨"}
# {"prompt": "2번 핑키 10 테이블 청소 완료해", "pinky_id": "2", "pinky_response": "cleaning", "table_id": "10번 테이블 청소 완료했습니다 🧹"}
# {"prompt": "핑키들 1 테이블 생일 준비해!", "pinky_id": "", "pinky_response": "birthday", "table_id": "1번 테이블 생일 준비 완료하겠습니다 🎂"}
# {"prompt": "2번 핑키 3 테이블 생일 축하해줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "3번 테이블 손님을 위한 생일 축하를 준비할게요 🎉"}
# {"prompt": "핑키야 5 테이블 생일 이벤트 시작해", "pinky_id": "", "pinky_response": "birthday", "table_id": "5번 테이블 생일 이벤트를 시작하겠습니다 🎈"}
# {"prompt": "3번 핑키 2 테이블에 케이크 서빙해줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "2번 테이블로 케이크를 서빙하겠습니다 🎂"}
# {"prompt": "1번 핑키 4 테이블 생일 노래 틀어줘", "pinky_id": "1", "pinky_response": "birthday", "table_id": "4번 테이블에 생일 축하 노래를 틀어드릴게요 🎶"}
# {"prompt": "핑키들 6 테이블 생일 풍선 달아줘", "pinky_id": "", "pinky_response": "birthday", "table_id": "6번 테이블에 생일 풍선을 달아드리겠습니다 🎈"}
# {"prompt": "4번 핑키 8 테이블 깜짝 이벤트 해줘", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블에 깜짝 이벤트를 준비하겠습니다 🎊"}
# {"prompt": "핑키야 7 테이블 생일 파티 준비", "pinky_id": "", "pinky_response": "birthday", "table_id": "7번 테이블 생일 파티를 준비하겠습니다 🎉"}
# {"prompt": "2번 핑키 9 테이블 생일 선물 전달해줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "9번 테이블에 생일 선물을 전달하겠습니다 🎁"}
# {"prompt": "3번 핑키 10 테이블 생일 사진 찍어줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "10번 테이블에서 생일 사진을 촬영하겠습니다 📸"}
# {"prompt": "1번 핑키 1 테이블 생일 장식 추가해", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블을 화려하게 장식하겠습니다 🎀"}
# {"prompt": "2번 핑키 2 테이블 케이크 촛불 켜줘", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블 케이크 촛불을 켜겠습니다 🕯️"}
# {"prompt": "3번 핑키 3 테이블 생일 카드 전달해줘", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블에 생일 카드를 전달할게요 💌"}
# {"prompt": "4번 핑키 4 테이블 축하 인사 부탁해", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블에 따뜻한 축하 인사를 드리겠습니다 🌟"}
# {"prompt": "핑키야 5 테이블 생일 사진 찍자", "pinky_id": "", "pinky_response": "birthday", "table_id": "5번 테이블에서 생일 사진을 찍겠습니다 📸"}
# {"prompt": "6 테이블 생일 케이크 가져다줘 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "6번 테이블로 생일 케이크를 서빙하겠습니다 🎂"}
# {"prompt": "7 테이블 생일 풍선 달기 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "7번 테이블에 생일 풍선을 장식하겠습니다 🎈"}
# {"prompt": "8 테이블 생일 축하 세팅해 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "8번 테이블을 생일 축하 세팅하겠습니다 🎉"}
# {"prompt": "9 테이블 깜짝 생일 이벤트 해 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "9번 테이블에 깜짝 생일 이벤트를 준비하겠습니다 🎊"}
# {"prompt": "10 테이블 생일송 불러줘 핑키들", "pinky_id": "", "pinky_response": "birthday", "table_id": "10번 테이블 손님을 위해 생일송을 불러드릴게요 🎶"}
# {"prompt": "1 테이블 생일 파티 모드로 해 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블을 생일 파티 분위기로 바꿉니다 🎉"}
# {"prompt": "2 테이블 생일 케이크 추가 주문 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블에 케이크 추가 주문을 반영하겠습니다 🍰"}
# {"prompt": "3 테이블 생일 기념 사진 촬영 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블에서 생일 기념 사진을 촬영합니다 📸"}
# {"prompt": "4 테이블 생일 축하 풍선 달아줘 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블에 축하 풍선을 달아드리겠습니다 🎈"}
# {"prompt": "5 테이블 깜짝 생일 축하 준비 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "5번 테이블에 깜짝 생일 축하를 준비합니다 🎊"}
# {"prompt": "6 테이블 생일 선물 준비 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "6번 테이블에 생일 선물을 준비하겠습니다 🎁"}
# {"prompt": "7 테이블 생일 초 켜줘 3번 핑키", "pinky_id": "3", "pinky_response": "birthday", "table_id": "7번 테이블 케이크에 초를 켜겠습니다 🕯️"}
# {"prompt": "8 테이블 생일 이벤트 시작해 4번 핑키", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블의 생일 이벤트를 시작합니다 🎉"}
# {"prompt": "9 테이블 생일 축하 인사 1번 핑키", "pinky_id": "1", "pinky_response": "birthday", "table_id": "9번 테이블에 축하 인사를 드리겠습니다 🌟"}
# {"prompt": "10 테이블 생일 디저트 서빙 2번 핑키", "pinky_id": "2", "pinky_response": "birthday", "table_id": "10번 테이블에 디저트를 서빙하겠습니다 🍰"}
# {"prompt": "1번 핑키 1 테이블 생일 장식 완성", "pinky_id": "1", "pinky_response": "birthday", "table_id": "1번 테이블 생일 장식을 완성했습니다 🎀"}
# {"prompt": "2번 핑키 2 테이블 축하 메시지 전달", "pinky_id": "2", "pinky_response": "birthday", "table_id": "2번 테이블에 축하 메시지를 전달합니다 💌"}
# {"prompt": "3번 핑키 3 테이블 생일 케이크 준비", "pinky_id": "3", "pinky_response": "birthday", "table_id": "3번 테이블 케이크를 준비하겠습니다 🎂"}
# {"prompt": "4번 핑키 4 테이블 파티 준비 완료", "pinky_id": "4", "pinky_response": "birthday", "table_id": "4번 테이블 파티 준비를 완료했습니다 🎉"}
# {"prompt": "1번 핑키 5 테이블 생일 기념사진 찍기", "pinky_id": "1", "pinky_response": "birthday", "table_id": "5번 테이블에서 기념사진을 찍겠습니다 📸"}
# {"prompt": "2번 핑키 6 테이블 풍선 세팅", "pinky_id": "2", "pinky_response": "birthday", "table_id": "6번 테이블에 풍선을 세팅하겠습니다 🎈"}
# {"prompt": "3번 핑키 7 테이블 축하 이벤트 진행", "pinky_id": "3", "pinky_response": "birthday", "table_id": "7번 테이블 축하 이벤트를 진행합니다 🎊"}
# {"prompt": "4번 핑키 8 테이블 케이크 촛불 준비", "pinky_id": "4", "pinky_response": "birthday", "table_id": "8번 테이블 케이크에 촛불을 준비합니다 🕯️"}
# {"prompt": "1번 핑키 9 테이블 생일 노래 틀어줘", "pinky_id": "1", "pinky_response": "birthday", "table_id": "9번 테이블 생일 노래를 틀어드릴게요 🎶"}
# {"prompt": "2번 핑키 10 테이블 생일 축하 시작", "pinky_id": "2", "pinky_response": "birthday", "table_id": "10번 테이블 생일 축하를 시작합니다 🎉"}
# {"prompt": "핑키들", "pinky_id": " 지금 매장에 화재 발생!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 매장에 연기 나!", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "1번 핑키", "pinky_id": " 가스 누출 같아!", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 전기 문제 발생!", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 손님이 넘어졌어!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "4번 핑키", "pinky_id": " 매장에 물이 새!", "pinky_response": "4", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 대피 방송 시작해", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 화재 경보 울렸어!", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "1번 핑키", "pinky_id": " 응급 상황 발생!", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 매장 긴급 정전!", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "2 테이블 화재 발견 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "2번 테이블 화재 확인! 손님 대피 안내하겠습니다 🚨"}
# {"prompt": "5 테이블 손님이 다쳤어 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "5번 테이블 부상자 대응 준비 완료했습니다 🚑"}
# {"prompt": "6 테이블 물이 새고 있어 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "6번 테이블 주변 물 새는 곳을 조치하겠습니다 💦"}
# {"prompt": "7 테이블 전기 스파크 발생 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 전기 문제 즉시 대응하겠습니다 ⚡"}
# {"prompt": "8 테이블 화재 위험 발견 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "8번 테이블 화재 위험 인지! 즉시 대피 안내하겠습니다 🚨"}
# {"prompt": "9 테이블 가스 냄새가 나 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "9번 테이블 가스 냄새 확인! 긴급 조치합니다 🛑"}
# {"prompt": "10 테이블 주변 물기 발생 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "10번 테이블 물기 제거 및 안내 진행합니다 💧"}
# {"prompt": "1 테이블 손님 의식 잃음 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "1번 테이블 응급 구조 요청합니다 🏥"}
# {"prompt": "2 테이블 긴급 구조 요청 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "2번 테이블 긴급 구조를 요청했습니다 🚑"}
# {"prompt": "3 테이블 매장 전원 나감 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "3번 테이블 주변 전원 이상 대응합니다 💡"}
# {"prompt": "4 테이블 주변 화재 감지 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "4번 테이블 주변 화재 대응을 시작합니다 🚒"}
# {"prompt": "5 테이블 손님 대피 안내 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "5번 테이블 손님을 안전하게 대피 안내하겠습니다 📢"}
# {"prompt": "6 테이블 주변 물 난리 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "6번 테이블 주변 물기를 긴급 정리하겠습니다 💧"}
# {"prompt": "7 테이블 불꽃 튐 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 불꽃 발생 대응 시작합니다 🔥"}
# {"prompt": "8 테이블 가스 경고 울림 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "8번 테이블 가스 경고 확인! 긴급 대응합니다 🛑"}
# {"prompt": "9 테이블 손님 넘어짐 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "9번 테이블 손님 부상 응급 처치하겠습니다 🚑"}
# {"prompt": "10 테이블 긴급 사태 발생 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "10번 테이블 긴급 사태 대응을 시작합니다 🆘"}
# {"prompt": "1번 핑키", "pinky_id": " 매장 가스 경보 울림", "pinky_response": "1", "table_id": "emergency"}
# {"prompt": "2번 핑키", "pinky_id": " 화재 위험 신호 감지", "pinky_response": "2", "table_id": "emergency"}
# {"prompt": "3번 핑키", "pinky_id": " 매장 물기 심함", "pinky_response": "3", "table_id": "emergency"}
# {"prompt": "4번 핑키", "pinky_id": " 전력 차단 발생", "pinky_response": "4", "table_id": "emergency"}
# {"prompt": "핑키들", "pinky_id": " 매장 화재 진압 시도", "pinky_response": "", "table_id": "emergency"}
# {"prompt": "1 테이블 주변 불꽃 감지 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "1번 테이블 주변 불꽃을 긴급 진압하겠습니다 🔥"}
# {"prompt": "2 테이블 가스 누출 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "2번 테이블 가스 누출 조치하겠습니다 🛑"}
# {"prompt": "3 테이블 소화기 사용 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "3번 테이블 소화기를 사용해 진압하겠습니다 🧯"}
# {"prompt": "4 테이블 전기 스파크 발견 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "4번 테이블 전기 문제 긴급 대응합니다 ⚡"}
# {"prompt": "5 테이블 손님 심정지 발생 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "5번 테이블 손님 긴급 심폐소생술 시작합니다 🏥"}
# {"prompt": "6 테이블 구조 요청 1번 핑키", "pinky_id": "1", "pinky_response": "emergency", "table_id": "6번 테이블 구조 요청 신속 대응합니다 🚑"}
# {"prompt": "7 테이블 응급 조치 2번 핑키", "pinky_id": "2", "pinky_response": "emergency", "table_id": "7번 테이블 응급 조치 실시합니다 🏥"}
# {"prompt": "8 테이블 전기 문제 조치 3번 핑키", "pinky_id": "3", "pinky_response": "emergency", "table_id": "8번 테이블 전기 문제 조치합니다 ⚡"}
# {"prompt": "9 테이블 화재 대피 시작 4번 핑키", "pinky_id": "4", "pinky_response": "emergency", "table_id": "9번 테이블 손님 대피 시작합니다 🚒"}
# {"prompt": "10 테이블 대피 안내 방송 핑키들", "pinky_id": "", "pinky_response": "emergency", "table_id": "10번 테이블 대피 안내 방송을 시작합니다 📢"}
# {"prompt": "1번 핑키 2 테이블에 물 서빙해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "2번 테이블로 시원한 물을 서빙하겠습니다 💧"}
# {"prompt": "2번 핑키 4 테이블에 음료 가져다줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "4번 테이블로 음료를 빠르게 가져다드릴게요 🥤"}
# {"prompt": "3번 핑키 1 테이블에 샐러드 서빙해줘", "pinky_id": "3", "pinky_response": "serving", "table_id": "1번 테이블로 신선한 샐러드를 서빙합니다 🥗"}
# {"prompt": "핑키들 5 테이블에 메인 요리 서빙해줘", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블로 메인 요리를 서빙하겠습니다 🍽️"}
# {"prompt": "4번 핑키 6 테이블에 디저트 나르기", "pinky_id": "4", "pinky_response": "serving", "table_id": "6번 테이블에 달콤한 디저트를 나르겠습니다 🍰"}
# {"prompt": "1번 핑키 3 테이블에 추가 주문 전달해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "3번 테이블 추가 주문을 전달하겠습니다 🛎️"}
# {"prompt": "2번 핑키 7 테이블에 맥주 서빙해줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블로 시원한 맥주를 서빙합니다 🍺"}
# {"prompt": "3번 핑키 8 테이블에 와인 서빙해줘", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블에 와인을 서빙하겠습니다 🍷"}
# {"prompt": "핑키야 9 테이블에 에피타이저 가져다줘", "pinky_id": "", "pinky_response": "serving", "table_id": "9번 테이블로 에피타이저를 가져다드릴게요 🥟"}
# {"prompt": "4번 핑키 10 테이블에 추가 물 서빙", "pinky_id": "4", "pinky_response": "serving", "table_id": "10번 테이블에 추가 물을 서빙하겠습니다 💧"}
# {"prompt": "1 테이블에 생수 가져다줘 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "1번 테이블로 생수를 서빙하겠습니다 🚰"}
# {"prompt": "2 테이블에 커피 서빙해줘 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "2번 테이블로 따뜻한 커피를 서빙합니다 ☕"}
# {"prompt": "3 테이블에 티 서빙해 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "3번 테이블에 따뜻한 티를 가져다드릴게요 🍵"}
# {"prompt": "4 테이블에 탄산음료 전달 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "4번 테이블에 탄산음료를 전달합니다 🥤"}
# {"prompt": "5 테이블에 핫초코 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블에 따뜻한 핫초코를 서빙합니다 🍫"}
# {"prompt": "6 테이블에 아이스커피 서빙 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "6번 테이블에 시원한 아이스커피를 서빙합니다 ❄️"}
# {"prompt": "7 테이블에 에이드 가져다줘 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블에 에이드를 가져다드릴게요 🍹"}
# {"prompt": "8 테이블에 추가 음료 요청 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블 추가 음료를 준비합니다 🥤"}
# {"prompt": "9 테이블에 디저트 나르기 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "9번 테이블에 달콤한 디저트를 서빙합니다 🍰"}
# {"prompt": "10 테이블에 스테이크 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "10번 테이블로 스테이크를 서빙하겠습니다 🥩"}
# {"prompt": "1번 핑키 1 테이블에 감자튀김 서빙해줘", "pinky_id": "1", "pinky_response": "serving", "table_id": "1번 테이블에 바삭한 감자튀김을 서빙하겠습니다 🍟"}
# {"prompt": "2번 핑키 2 테이블에 피자 가져다줘", "pinky_id": "2", "pinky_response": "serving", "table_id": "2번 테이블에 따끈한 피자를 서빙합니다 🍕"}
# {"prompt": "3번 핑키 3 테이블에 파스타 서빙해", "pinky_id": "3", "pinky_response": "serving", "table_id": "3번 테이블로 맛있는 파스타를 가져다드릴게요 🍝"}
# {"prompt": "4번 핑키 4 테이블에 리필 음료 가져다줘", "pinky_id": "4", "pinky_response": "serving", "table_id": "4번 테이블로 음료를 리필해드리겠습니다 🥤"}
# {"prompt": "핑키들 5 테이블에 생과일주스 서빙", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블로 생과일주스를 서빙하겠습니다 🍹"}
# {"prompt": "6 테이블에 추가 디저트 요청 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "6번 테이블에 추가 디저트를 가져다드릴게요 🍰"}
# {"prompt": "7 테이블에 아이스크림 서빙 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블에 시원한 아이스크림을 서빙합니다 🍨"}
# {"prompt": "8 테이블에 샐러드 리필 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블 샐러드를 리필해드리겠습니다 🥗"}
# {"prompt": "9 테이블에 치즈 플래터 서빙 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "9번 테이블로 치즈 플래터를 서빙하겠습니다 🧀"}
# {"prompt": "10 테이블에 스무디 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "10번 테이블에 스무디를 가져다드릴게요 🍹"}
# {"prompt": "1 테이블에 핫커피 리필 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "1번 테이블에 핫커피를 리필해드릴게요 ☕"}
# {"prompt": "2 테이블에 음료 추가 요청 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "2번 테이블 추가 음료를 준비합니다 🥤"}
# {"prompt": "3 테이블에 물 다시 서빙 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "3번 테이블에 물을 다시 서빙하겠습니다 💧"}
# {"prompt": "4 테이블에 추가 디저트 서빙 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "4번 테이블 추가 디저트를 서빙합니다 🍰"}
# {"prompt": "5 테이블에 에스프레소 서빙 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "5번 테이블에 에스프레소를 서빙하겠습니다 ☕"}
# {"prompt": "6 테이블에 맥주 추가 서빙 1번 핑키", "pinky_id": "1", "pinky_response": "serving", "table_id": "6번 테이블에 맥주를 추가로 서빙하겠습니다 🍺"}
# {"prompt": "7 테이블에 와인 추가 서빙 2번 핑키", "pinky_id": "2", "pinky_response": "serving", "table_id": "7번 테이블에 와인을 추가 서빙하겠습니다 🍷"}
# {"prompt": "8 테이블에 케이크 서빙 3번 핑키", "pinky_id": "3", "pinky_response": "serving", "table_id": "8번 테이블에 케이크를 서빙합니다 🍰"}
# {"prompt": "9 테이블에 핫티 서빙 4번 핑키", "pinky_id": "4", "pinky_response": "serving", "table_id": "9번 테이블에 따뜻한 티를 가져다드릴게요 🍵"}
# {"prompt": "10 테이블에 추가 스낵 가져다줘 핑키들", "pinky_id": "", "pinky_response": "serving", "table_id": "10번 테이블에 추가 스낵을 서빙하겠습니다 🍪"}
#
#     아래의 [조건]에 맞게 [탬플릿] 형식으로 JSON 답변을 생성해주세요:
#
#     [조건]
#     1. pinky_id는 "X번 핑키!"에서의 X 입니다. 이때 X가 없으면 pinky_id는 비워두세요.
#     2. pinky_task는 무조건 string형 cleaning 입니다.
#     3. pinky_response는 1번 핑키 2번 테이블이 더럽잖아.에 대한 string형 답변입니다.
#     4. table_id는 "X번 테이블"에서의 X 입니다. 반드시 X 이외의 다른 문장이 오면 안됩니다. 이때 X가 없으면 table_id는 비워두세요.
#     5. 위의 조건 이외에 다른 정수, 단어, 문장은 생성하지 않습니다.
#
#     [탬플릿] : 반드시 큰따옴표로 감싸서 문자열 형태로 출력해야 합니다. 반드시 문자열 이외의 형식은 출력하지 않습니다.
#     {
#         "pinky_id": "",
#         "pinky_task": "",
#         "pinky_response": "",
#         "table_id": ""
#     }
#
#
# > Finished chain.

# %%
chat_history = memory.load_memory_variables({})["chat_history"]
print(chat_history)
# Out:
# Human: 안녕 핑키! 오늘 하루는 좀 어때?
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "안녕하세요 주인님! 오늘 하루도 즐겁게 보내고 있어요 😊"
# }
# Human: 그래, 오늘 하루도 화이팅!
# AI: {
#     "pinky_id": "",
#     "pinky_task": "greetings",
#     "pinky_response": "네 주인님! 오늘도 힘내겠습니다 💪"
# }
# Human: 2번 핑키 1 테이블 청소해
# AI: {
#     "pinky_id": "2",
#     "pinky_task": "cleaning",
#     "pinky_response": "1번 테이블을 깨끗하게 정리하러 가겠습니다 🧹",
#     "table_id": "1번 테이블"
# }
# Human: 핑키들 4번 테이블 생일이래!
# AI: {
#     "pinky_id": "",
#     "pinky_task": "birthday",
#     "pinky_response": "4번 테이블 생일 축하를 준비하겠습니다 🎉",
#     "table_id": "4번 테이블"
# }
# Human: 핑키들, 지금 매장에 화재 발생!
# AI: {
#     "pinky_id": "",
#     "pinky_task": "emergency",
#     "pinky_response": "매장에 화재 발생! 즉시 대피하세요!",
#     "table_id": ""
# }
# Human: 1번 핑키 2번 테이블이 더럽잖아.
# AI: {
#     "pinky_id": "1",
#     "pinky_task": "cleaning",
#     "pinky_response": "2번 테이블을 깨끗하게 정리하러 가겠습니다 🧹",
#     "table_id": "2번 테이블"
# }

# %%
response1 = validate_alba_task_discriminator("안녕 핑키! 오늘 하루는 어때?")
print(response1)

response2 = validate_alba_task_discriminator("4번 테이블이 좀 더러운데?")
print(response2)

response3 = validate_alba_task_discriminator("1번 테이블 생일이래")
print(response3)

response4 = validate_alba_task_discriminator("2번 핑키 뭐가 보이는지 설명해")
print(response4)

response5 = validate_alba_task_discriminator("3번 핑키 오늘 주식 현황 알려줘")
print(response5)
# Out:
# greetings
# cleaning
# birthday
# camera on
# ['cleaning', 'serving', 'birthday', 'emergency', 'greetings', 'camera on']에 존재하지 않는 업무를 입력으로 받았습니다.
# None

# %%
response6 = validate_alba_task_discriminator("2번 핑키 뭐가 보이는지 설명해")
print(response6)

response7 = validate_alba_task_discriminator("2번 핑키 카메라 켜")
print(response7)

response8 = validate_alba_task_discriminator("3번 핑키 오늘 주식 현황 알려줘")
print(response8)

response9 = validate_alba_task_discriminator("테이블 상황을 알려줘")
print(response9)
# Out:
# camera on
# camera on
# ['cleaning', 'serving', 'birthday', 'emergency', 'greetings', 'camera on']에 존재하지 않는 업무를 입력으로 받았습니다.
# None
# ['cleaning', 'serving', 'birthday', 'emergency', 'greetings', 'camera on']에 존재하지 않는 업무를 입력으로 받았습니다.
# None

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.memory import ConversationBufferMemory
from langchain.chat_models import ChatOpenAI

from dotenv import load_dotenv
import time

load_dotenv()

# 메모리 생성 (기록 저장용)
memory = ConversationBufferMemory(memory_key="chat_history", input_key="user_query")

pinky_prompt = generate_pinky_response()
pinky_template = PromptTemplate(template = pinky_prompt, input_variables=["chat_history", "user_query"])

# 객체 생성
llm = ChatOpenAI(
    temperature=0.7,  # 창의성 (0.0 ~ 2.0)
    max_tokens=2048,  # 최대 토큰수
    model_name="gpt-4o-mini",  # 모델명
)

chain = LLMChain(
    llm=llm,
    prompt=pinky_template,
    memory=memory,
    verbose=True
)

# %%
# 대화 TCP 전송 테스트

import json
import socket
import logging

tcp_host = "192.168.0.156"
tcp_port = 8001

# get_logger 정의
def get_logger():
    logger = logging.getLogger("TCPClient")
    if not logger.handlers:
        logger.setLevel(logging.INFO)
        handler = logging.StreamHandler()
        formatter = logging.Formatter('[%(asctime)s] %(levelname)s - %(message)s')
        handler.setFormatter(formatter)
        logger.addHandler(handler)
    return logger

def send_tcp_data(data):
    try:
        with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock: #socket.SOCK_STREAM : TCP 통신
            sock.connect((tcp_host, tcp_port))
            sock.sendall(json.dumps(data).encode('utf-8'))
            response = sock.recv(1024).decode('utf-8')
            get_logger().info(f"서버 응답: {response}")
    except Exception as e:
        get_logger().error(f"TCP 연결 실패: {e}")

conv_1 = {
    "id": 10,
    "type": "CHATBOT",
    "question": "안녕 핑키!",
    "answer": "😊 Nice to meet you! As PINGKI, I'm here to assist the restaurant owner and provide helpful responses. What can I help you with today? 🤔",
}        

send_tcp_data(conv_1)
# Out:
# [2025-04-25 14:43:48,367] INFO - 서버 응답: ERROR
